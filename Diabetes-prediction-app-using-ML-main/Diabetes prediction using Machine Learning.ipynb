# %% [markdown]
# # **Predicting Diabetes using Machine Learning**

# %%
#importing reqd libraries
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("diabetes.csv")

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df['Outcome'].value_counts()
# Out:
# 0    500
# 1    268
# Name: Outcome, dtype: int64

# %%
df.shape
# Out:
# (768, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.isna().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
print('Total zero Glucose values: ' + str(df[df['Glucose']==0].shape[0]))
print('Total zero BloodPressure values: ' + str(df[df['BloodPressure']==0].shape[0]))
print('Total zero SkinThickness values: ' + str(df[df['SkinThickness']==0].shape[0]))
print('Total zero Insulin values: ' + str(df[df['Insulin']==0].shape[0]))
print('Total zero BMI values: ' + str(df[df['BMI']==0].shape[0]))
print('Total zero DiabetesPedigreeFunction values: ' + str(df[df['DiabetesPedigreeFunction']==0].shape[0]))
print('Total zero Age values: ' + str(df[df['Age']==0].shape[0]))
# Out:
# Total zero Glucose values: 5
# Total zero BloodPressure values: 35
# Total zero SkinThickness values: 227
# Total zero Insulin values: 374
# Total zero BMI values: 11
# Total zero DiabetesPedigreeFunction values: 0
# Total zero Age values: 0

# %%
df[df['Glucose']==0]['Outcome'].value_counts()
# Out:
# 0    3
# 1    2
# Name: Outcome, dtype: int64

# %%
df[df['BloodPressure']==0]['Outcome'].value_counts()
# Out:
# 0    19
# 1    16
# Name: Outcome, dtype: int64

# %%
df[df['SkinThickness']==0]['Outcome'].value_counts()
# Out:
# 0    139
# 1     88
# Name: Outcome, dtype: int64

# %%
df[df['Insulin']==0]['Outcome'].value_counts()
# Out:
# 0    236
# 1    138
# Name: Outcome, dtype: int64

# %%
df[df['BMI']==0]['Outcome'].value_counts()
# Out:
# 0    9
# 1    2
# Name: Outcome, dtype: int64

# %%
def replace_zero(df):
    df_nan = df.copy(deep=True)
    cols = ["Glucose","BloodPressure","SkinThickness","Insulin","BMI"]
    df_nan[cols] = df_nan[cols].replace({0:np.nan})
    return df_nan

df_nan=replace_zero(df)

# %%
df_nan.head(2)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6    148.0           72.0           35.0      NaN  33.6
# 1            1     85.0           66.0           29.0      NaN  26.6
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0

# %%
df_nan[df_nan['Glucose'].isna()]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 75             1      NaN           48.0           20.0      NaN  24.7
# 182            1      NaN           74.0           20.0     23.0  27.7
# 342            1      NaN           68.0           35.0      NaN  32.0
# 349            5      NaN           80.0           32.0      NaN  41.0
# 502            6      NaN           68.0           41.0      NaN  39.0
#
#      DiabetesPedigreeFunction  Age  Outcome
# 75                      0.140   22        0
# 182                     0.299   21        0
# 342                     0.389   22        0
# 349                     0.346   37        1
# 502                     0.727   41        1

# %%
#finds the median of different attribute based on Outcome
def find_median(df, col):
    
    df_nondiab = df[df['Outcome']==0].reset_index(drop = True)
    df_diab = df[df['Outcome']==1].reset_index(drop = True)
    return(df_nondiab[col].median(), df_diab[col].median())

# %%
find_median(df_nan,'Glucose')
# Out:
# (107.0, 140.0)

# %%
df_nan.isna().sum()
# Out:
# Pregnancies                   0
# Glucose                       5
# BloodPressure                35
# SkinThickness               227
# Insulin                     374
# BMI                          11
# DiabetesPedigreeFunction      0
# Age                           0
# Outcome                       0
# dtype: int64

# %%
def replace_null(df,var):
    
    median_tuple=find_median(df,var)
    var_0 = median_tuple[0]
    var_1 = median_tuple[1]
    
    df.loc[(df['Outcome'] == 0) & (df[var].isnull()), var] = var_0
    df.loc[(df['Outcome'] == 1) & (df[var].isnull()), var] = var_1
        
    return df[var].isnull().sum()

# %%
replace_null(df_nan, 'Glucose' )
# Out:
# 0

# %%
replace_null(df_nan, 'BloodPressure' )
# Out:
# 0

# %%
replace_null(df_nan, 'SkinThickness' )
# Out:
# 0

# %%
replace_null(df_nan, 'Insulin' )
# Out:
# 0

# %%
replace_null(df_nan, 'BMI' )
# Out:
# 0

# %%
df_nan.isna().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df_nan.shape
# Out:
# (768, 9)

# %%
df.shape
# Out:
# (768, 9)

# %%
df = df_nan.copy()

# %%
column_list = list(df.columns)

# %%
column_list
# Out:
# ['Pregnancies',
#  'Glucose',
#  'BloodPressure',
#  'SkinThickness',
#  'Insulin',
#  'BMI',
#  'DiabetesPedigreeFunction',
#  'Age',
#  'Outcome']

# %%
df.shape
# Out:
# (768, 9)

# %%
df.shape
# Out:
# (768, 9)

# %%
df.head(2)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6    148.0           72.0           35.0    169.5  33.6
# 1            1     85.0           66.0           29.0    102.5  26.6
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LogisticRegression
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score
from sklearn.metrics import roc_curve
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import roc_auc_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import f1_score, make_scorer
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.manifold import TSNE
from sklearn.metrics import fbeta_score, make_scorer, precision_score, recall_score, confusion_matrix, accuracy_score

# %%
pca_x = df.copy()
pca_x = pca_x.drop(columns = "Outcome")

# %%
scaler = StandardScaler()
pca_x = pd.DataFrame(scaler.fit_transform(pca_x))

# %%
pca_x
# Out:
#             0         1         2         3         4         5         6  \
# 0    0.639947  0.864625 -0.032180  0.665181  0.311604  0.169483  0.468492
# 1   -0.844885 -1.204727 -0.528124 -0.010112 -0.440843 -0.848549 -0.365061
# 2    1.233880  2.014265 -0.693438  0.327535  0.311604 -1.328478  0.604397
# 3   -0.844885 -1.073339 -0.528124 -0.685405 -0.536303 -0.630399 -0.920763
# 4   -1.141852  0.503310 -2.677212  0.665181  0.294758  1.551096  5.484909
# ..        ...       ...       ...       ...       ...       ...       ...
# 763  1.827813 -0.679177  0.298449  2.128317  0.429525  0.067679 -0.908682
# 764 -0.547919  0.010607 -0.197495 -0.235210 -0.440843  0.634868 -0.398282
# 765  0.342981 -0.022240 -0.032180 -0.685405 -0.334153 -0.906722 -0.685193
# 766 -0.844885  0.141994 -1.024067  0.327535  0.311604 -0.339533 -0.371101
# 767 -0.844885 -0.941952 -0.197495  0.214986 -0.440843 -0.295903 -0.473785
#
#             7
# 0    1.425995
# 1   -0.190672
# 2   -0.105584
# 3   -1.041549
# 4   -0.020496
# ..        ...
# 763  2.532136
# 764 -0.531023
# 765 -0.275760
# 766  1.170732
# 767 -0.871374
#
# [768 rows x 8 columns]

# %%
pca_x.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.639947  0.864625 -0.032180  0.665181  0.311604  0.169483  0.468492
# 1 -0.844885 -1.204727 -0.528124 -0.010112 -0.440843 -0.848549 -0.365061
# 2  1.233880  2.014265 -0.693438  0.327535  0.311604 -1.328478  0.604397
# 3 -0.844885 -1.073339 -0.528124 -0.685405 -0.536303 -0.630399 -0.920763
# 4 -1.141852  0.503310 -2.677212  0.665181  0.294758  1.551096  5.484909
#
#           7
# 0  1.425995
# 1 -0.190672
# 2 -0.105584
# 3 -1.041549
# 4 -0.020496

# %%
pca_df = pd.DataFrame(df['Outcome'])

# %%
#visualizing using PCA

pca = PCA(n_components=2)
pca_result = pca.fit_transform(pca_x)
pca_df['pca-one'] = pca_result[:,0]
pca_df['pca-two'] = pca_result[:,1]

# %%
pca_df
# Out:
#      Outcome   pca-one   pca-two
# 0          1  1.575769 -0.613465
# 1          0 -1.575930  0.079637
# 2          1  0.734548 -0.543459
# 3          0 -2.131111  0.267265
# 4          1  0.804709  3.506736
# ..       ...       ...       ...
# 763        0  2.129022 -2.017483
# 764        0 -0.469797  0.607274
# 765        0 -0.894597 -0.837066
# 766        1 -0.070977 -0.004374
# 767        0 -1.292586  0.646618
#
# [768 rows x 3 columns]

# %%
pca_df.columns = ['Diabetic outcome','pca-one', 'pca-two']
print('Explained variation per principal component: {}'.format(pca.explained_variance_ratio_))
# Out:
# Explained variation per principal component: [0.29817668 0.18752573]

# %%
plt.figure(figsize=(10,7))
ax = sns.scatterplot(x="pca-one", y="pca-two",hue='Diabetic outcome', data=pca_df)

# %%
df_tsne = df.copy()

# %%
df_tsne.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6    148.0           72.0           35.0    169.5  33.6
# 1            1     85.0           66.0           29.0    102.5  26.6
# 2            8    183.0           64.0           32.0    169.5  23.3
# 3            1     89.0           66.0           23.0     94.0  28.1
# 4            0    137.0           40.0           35.0    168.0  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
y = df_tsne['Outcome']
df_tsne = df_tsne.drop(columns = 'Outcome')

# %%
df_tsne.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6    148.0           72.0           35.0    169.5  33.6
# 1            1     85.0           66.0           29.0    102.5  26.6
# 2            8    183.0           64.0           32.0    169.5  23.3
# 3            1     89.0           66.0           23.0     94.0  28.1
# 4            0    137.0           40.0           35.0    168.0  43.1
#
#    DiabetesPedigreeFunction  Age
# 0                     0.627   50
# 1                     0.351   31
# 2                     0.672   32
# 3                     0.167   21
# 4                     2.288   33

# %%
from sklearn.manifold import TSNE
model = TSNE(learning_rate=50)
tsne_features = model.fit_transform(df_tsne)

# %%
plt.figure(figsize=(10, 5))
plt.title('T-SNE plot to vizualize Diabetic vs Non-Diabetic people')
sns.scatterplot(x = tsne_features[:,0], y = tsne_features[:,1], hue = y)
plt.show()

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6    148.0           72.0           35.0    169.5  33.6
# 1            1     85.0           66.0           29.0    102.5  26.6
# 2            8    183.0           64.0           32.0    169.5  23.3
# 3            1     89.0           66.0           23.0     94.0  28.1
# 4            0    137.0           40.0           35.0    168.0  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
data = df.copy()

# %%
Y = data.Outcome
X = data.drop("Outcome", axis = 1)

# %%
columns = X.columns

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.20, random_state = 20, stratify=Y)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
std = scaler.fit(X_train)

#save
import pickle
pickle.dump(std, open('std.pkl','wb'))


X_train = std.transform(X_train)
X_test = std.transform(X_test)
X_train = pd.DataFrame(X_train, columns = columns)
X_test = pd.DataFrame(X_test, columns = columns)
X_train.head()
# Out:
#    Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 0    -0.531978 -0.706880      -0.186385       2.489469 -0.956673  1.157236
# 1     0.057083 -0.113681      -0.186385      -0.237913 -0.454062  1.742852
# 2     1.824269 -0.673925       0.318498       2.053088  0.402033  0.044565
# 3    -0.826509 -0.838703      -0.691267      -0.237913 -0.625281  0.088486
# 4     1.235207 -0.871658      -0.018090      -0.237913 -0.454062  0.615541
#
#    DiabetesPedigreeFunction       Age
# 0                  0.631014 -0.693698
# 1                  1.334750 -0.608986
# 2                 -0.937667  2.525347
# 3                 -0.571848 -1.032545
# 4                  0.035783  2.017077

# %%
X_test
# Out:
#      Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 0      -1.121040 -0.245503       0.655087       0.525754  1.561903  1.698931
# 1      -0.531978 -0.311414       1.159969       1.398516  0.181105  0.849787
# 2       0.057083  0.018142      -0.354679      -0.237913 -0.454062  0.352014
# 3      -0.826509 -0.805747      -0.186385      -1.547056 -0.454062 -2.107575
# 4       1.824269  1.336364       0.991675      -0.237913 -0.454062 -0.716736
# ..           ...       ...            ...            ...       ...       ...
# 149     0.351614  0.347697       0.655087      -0.237913 -0.454062 -0.848500
# 150     0.940676 -0.080725      -0.186385      -0.237913 -0.454062 -1.082746
# 151     0.351614 -1.102347      -0.522973      -0.892485 -1.332250 -1.199869
# 152    -0.237448  0.215875      -0.018090      -0.456104  0.512497 -0.028637
# 153     0.646145 -0.476192       1.328264      -0.237913 -0.454062  0.615541
#
#      DiabetesPedigreeFunction       Age
# 0                   -0.950067 -0.524274
# 1                   -0.705155 -0.439563
# 2                   -0.246331 -0.354851
# 3                   -1.012071 -1.032545
# 4                   -0.903565  1.762942
# ..                        ...       ...
# 149                 -0.891164  3.033618
# 150                 -0.819861  0.322843
# 151                 -0.407540 -0.270139
# 152                  0.234193 -0.524274
# 153                  0.786022 -0.185428
#
# [154 rows x 8 columns]

# %%
#Building Logistic Regression model on the Standardized variables

from sklearn.linear_model import LogisticRegression
lr_std = LogisticRegression(random_state = 20,penalty='l2')
lr_std.fit(X_train, y_train)
y_pred = lr_std.predict(X_test)
print('Accuracy of logistic regression on test set with standardized features: {:.2f}'.format(lr_std.score(X_test, y_test)))
# Out:
# Accuracy of logistic regression on test set with standardized features: 0.83

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.20, random_state = 20, stratify=Y)

# %%
from sklearn.preprocessing import MinMaxScaler
norm = MinMaxScaler()
norm = norm.fit(X_train)
X_train = norm.transform(X_train)
X_test = norm.transform(X_test)
X_train = pd.DataFrame(X_train, columns = columns)
X_test = pd.DataFrame(X_test, columns = columns)
X_train.head()
# Out:
#    Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 0     0.117647  0.361290       0.469388       0.489130  0.051683  0.456033
# 1     0.235294  0.477419       0.469388       0.217391  0.106370  0.537832
# 2     0.588235  0.367742       0.530612       0.445652  0.199519  0.300613
# 3     0.058824  0.335484       0.408163       0.217391  0.087740  0.306748
# 4     0.470588  0.329032       0.489796       0.217391  0.106370  0.380368
#
#    DiabetesPedigreeFunction       Age
# 0                  0.255764  0.066667
# 1                  0.352690  0.083333
# 2                  0.039710  0.700000
# 3                  0.090094  0.000000
# 4                  0.173783  0.600000

# %%
X_test.head()
# Out:
#    Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 0     0.000000  0.451613       0.571429       0.293478  0.325721  0.531697
# 1     0.117647  0.438710       0.632653       0.380435  0.175481  0.413088
# 2     0.235294  0.503226       0.448980       0.217391  0.106370  0.343558
# 3     0.058824  0.341935       0.469388       0.086957  0.106370  0.000000
# 4     0.588235  0.761290       0.612245       0.217391  0.106370  0.194274
#
#    DiabetesPedigreeFunction       Age
# 0                  0.038002  0.100000
# 1                  0.071734  0.116667
# 2                  0.134927  0.133333
# 3                  0.029462  0.000000
# 4                  0.044406  0.550000

# %%
#Building Logistic Regression model on the Standardized variables

from sklearn.linear_model import LogisticRegression
lr_std = LogisticRegression(random_state = 20,penalty='l2')
lr_std.fit(X_train, y_train)
y_pred = lr_std.predict(X_test)
print('Accuracy of logistic regression on test set with normalized features: {:.2f}'.format(lr_std.score(X_test, y_test)))
# Out:
# Accuracy of logistic regression on test set with normalized features: 0.82

# %%
# Plotting the histograms of each variable
from matplotlib import pyplot
data.hist(alpha=0.5, figsize=(20, 10))
pyplot.show()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.20, random_state = 20, stratify=Y)

# %%
type(X_train)
# Out:
# pandas.core.frame.DataFrame

# %%
X_train_std = X_train[['BMI','BloodPressure', 'Glucose']]
X_test_std = X_test[['BMI','BloodPressure', 'Glucose']]

# %%
X_train_norm = X_train[['Age','DiabetesPedigreeFunction','Insulin','Pregnancies','SkinThickness']]
X_test_norm = X_test[['Age','DiabetesPedigreeFunction','Insulin','Pregnancies','SkinThickness']]

# %%
X_train_std.head()
# Out:
#       BMI  BloodPressure  Glucose
# 275  40.5           70.0    100.0
# 699  44.5           70.0    118.0
# 763  32.9           76.0    101.0
# 208  33.2           64.0     96.0
# 344  36.8           72.0     95.0

# %%
colums_std = ['BMI','BloodPressure', 'Glucose']
columns_norm = ['Age','DiabetesPedigreeFunction','Insulin','Pregnancies','SkinThickness']

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
std = scaler.fit(X_train_std)
X_train_std = std.transform(X_train_std)
X_test_std = std.transform(X_test_std)
X_train_std = pd.DataFrame(X_train_std, columns = colums_std)
X_test_std = pd.DataFrame(X_test_std, columns = colums_std)
X_train_std.head()
# Out:
#         BMI  BloodPressure   Glucose
# 0  1.157236      -0.186385 -0.706880
# 1  1.742852      -0.186385 -0.113681
# 2  0.044565       0.318498 -0.673925
# 3  0.088486      -0.691267 -0.838703
# 4  0.615541      -0.018090 -0.871658

# %%
from sklearn.preprocessing import MinMaxScaler
norm = MinMaxScaler()
norm = norm.fit(X_train_norm)
X_train_norm = norm.transform(X_train_norm)
X_test_norm = norm.transform(X_test_norm)
X_train_norm = pd.DataFrame(X_train_norm, columns = columns_norm)
X_test_norm = pd.DataFrame(X_test_norm, columns = columns_norm)
X_train_norm.head()
# Out:
#         Age  DiabetesPedigreeFunction   Insulin  Pregnancies  SkinThickness
# 0  0.066667                  0.255764  0.051683     0.117647       0.489130
# 1  0.083333                  0.352690  0.106370     0.235294       0.217391
# 2  0.700000                  0.039710  0.199519     0.588235       0.445652
# 3  0.000000                  0.090094  0.087740     0.058824       0.217391
# 4  0.600000                  0.173783  0.106370     0.470588       0.217391

# %%
X_train = pd.concat([X_train_std, X_train_norm], axis=1)
X_test = pd.concat([X_test_std, X_test_norm], axis=1)

# %%
X_train.head(2)
# Out:
#         BMI  BloodPressure   Glucose       Age  DiabetesPedigreeFunction  \
# 0  1.157236      -0.186385 -0.706880  0.066667                  0.255764
# 1  1.742852      -0.186385 -0.113681  0.083333                  0.352690
#
#     Insulin  Pregnancies  SkinThickness
# 0  0.051683     0.117647       0.489130
# 1  0.106370     0.235294       0.217391

# %%
X_test
# Out:
#           BMI  BloodPressure   Glucose       Age  DiabetesPedigreeFunction  \
# 0    1.698931       0.655087 -0.245503  0.100000                  0.038002
# 1    0.849787       1.159969 -0.311414  0.116667                  0.071734
# 2    0.352014      -0.354679  0.018142  0.133333                  0.134927
# 3   -2.107575      -0.186385 -0.805747  0.000000                  0.029462
# 4   -0.716736       0.991675  1.336364  0.550000                  0.044406
# ..        ...            ...       ...       ...                       ...
# 149 -0.848500       0.655087  0.347697  0.800000                  0.046114
# 150 -1.082746      -0.186385 -0.080725  0.266667                  0.055935
# 151 -1.199869      -0.522973 -1.102347  0.150000                  0.112724
# 152 -0.028637      -0.018090  0.215875  0.100000                  0.201110
# 153  0.615541       1.328264 -0.476192  0.166667                  0.277114
#
#       Insulin  Pregnancies  SkinThickness
# 0    0.325721     0.000000       0.293478
# 1    0.175481     0.117647       0.380435
# 2    0.106370     0.235294       0.217391
# 3    0.106370     0.058824       0.086957
# 4    0.106370     0.588235       0.217391
# ..        ...          ...            ...
# 149  0.106370     0.294118       0.217391
# 150  0.106370     0.411765       0.217391
# 151  0.010817     0.294118       0.152174
# 152  0.211538     0.176471       0.195652
# 153  0.106370     0.352941       0.217391
#
# [154 rows x 8 columns]

# %%
y_test
# Out:
# 162    0
# 620    0
# 233    0
# 438    0
# 660    0
#       ..
# 123    0
# 222    0
# 52     0
# 541    1
# 439    0
# Name: Outcome, Length: 154, dtype: int64

# %%
#Building Logistic Regression model on the Standardized variables

from sklearn.linear_model import LogisticRegression
lr_std = LogisticRegression(random_state = 20,penalty='l2')
lr_std.fit(X_train, y_train)
y_pred = lr_std.predict(X_test)
print('Accuracy of logistic regression on test set with normalized features: {:.2f}'.format(lr_std.score(X_test, y_test)))
# Out:
# Accuracy of logistic regression on test set with normalized features: 0.82

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.20, random_state = 20, stratify=Y)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
std = scaler.fit(X_train)
X_train = std.transform(X_train)
X_test = std.transform(X_test)
X_train = pd.DataFrame(X_train, columns = columns)
X_test = pd.DataFrame(X_test, columns = columns)
X_train.head()
# Out:
#    Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 0    -0.531978 -0.706880      -0.186385       2.489469 -0.956673  1.157236
# 1     0.057083 -0.113681      -0.186385      -0.237913 -0.454062  1.742852
# 2     1.824269 -0.673925       0.318498       2.053088  0.402033  0.044565
# 3    -0.826509 -0.838703      -0.691267      -0.237913 -0.625281  0.088486
# 4     1.235207 -0.871658      -0.018090      -0.237913 -0.454062  0.615541
#
#    DiabetesPedigreeFunction       Age
# 0                  0.631014 -0.693698
# 1                  1.334750 -0.608986
# 2                 -0.937667  2.525347
# 3                 -0.571848 -1.032545
# 4                  0.035783  2.017077

# %%
#Building Logistic Regression model on the Standardized variables

from sklearn.linear_model import LogisticRegression
lr_std = LogisticRegression(random_state = 20,penalty='l2')
lr_std.fit(X_train, y_train)
y_pred = lr_std.predict(X_test)
print('Accuracy of logistic regression on test set with standardized features: {:.2f}'.format(lr_std.score(X_test, y_test)))
# Out:
# Accuracy of logistic regression on test set with standardized features: 0.83

# %%
from sklearn.neighbors import KNeighborsClassifier
test_scores = []
train_scores = []
for i in range(5,15):
    neigh = KNeighborsClassifier(n_neighbors=i)
    neigh.fit(X_train, y_train)
    train_scores.append(neigh.score(X_train,y_train))
    test_scores.append(neigh.score(X_test,y_test))

# %%
print('Max train_scores is ' + str(max(train_scores)*100) + ' for k = '+ 
      str(train_scores.index(max(train_scores))+5))
# Out:
# Max train_scores is 85.50488599348535 for k = 11

# %%
print('Max test_scores is ' + str(max(test_scores)*100) + ' for k = '+ 
      str(test_scores.index(max(test_scores))+5))
# K=13 has generalized well for our data.
# Out:
# Max test_scores is 87.01298701298701 for k = 13

# %%
#Support Vector Machines
from sklearn import svm
svm_model = svm.SVC(probability=True).fit(X_train, y_train)
svm_pred=svm_model.predict(X_test)
svm_model.score(X_test, y_test)
# Almost 89% Accuracy
# Out:
# 0.8831168831168831

# %%
X_train.shape
# Out:
# (614, 8)

# %%
from sklearn.model_selection import GridSearchCV
clf = RandomForestClassifier(random_state = 20)

# use a full grid over all parameters
param_grid = {'n_estimators' : [50,100,150], "max_depth": [3, 5, 7],
              "max_features": [1, 3, 5, 7, 8]
              }

# run grid search
grid = GridSearchCV(clf, param_grid, cv=5,scoring='accuracy')

grid.fit(X_train, y_train)
print("Grid-Search with accuracy")
print("Best parameters:", grid.best_params_)
print("Best cross-validation score (accuracy)): {:.3f}".format(grid.best_score_))
# Out:
# Grid-Search with accuracy
# Best parameters: {'max_depth': 7, 'max_features': 3, 'n_estimators': 100}
# Best cross-validation score (accuracy)): 0.880

# %%
from sklearn.metrics import accuracy_score

# %%
rfc = RandomForestClassifier(n_estimators= 100, max_features= 3, max_depth= 7)
rfc.fit(X_train, y_train)

y_pr=rfc.predict(X_test)
print("Test set accuracy: {:.3f}".format(accuracy_score(y_test, y_pr)))

confusion_matrix(y_test, y_pr)
# Out:
# Test set accuracy: 0.890
# array([[91,  9],
#        [ 8, 46]], dtype=int64)

# %%
clf = GradientBoostingClassifier(random_state=20)
# use a full grid over all parameters
param_grid = {'n_estimators' : [50,100,150], "max_depth": [2,5,7,8],
              "max_features": [2,3,5, 7] ,'learning_rate' : [0.05, 0.075, 0.1, 0.25, 0.5, 0.75, 1]
              }
# run grid search
grid = GridSearchCV(clf, param_grid, cv=5,scoring='accuracy')
grid.fit(X_train, y_train)
print("Grid-Search with accuracy")
print("Best parameters:", grid.best_params_)
print("Best cross-validation score (accuracy)): {:.3f}".format(grid.best_score_))
# Out:
# Grid-Search with accuracy
# Best parameters: {'learning_rate': 0.075, 'max_depth': 5, 'max_features': 2, 'n_estimators': 50}
# Best cross-validation score (accuracy)): 0.888

# %%
gbc = GradientBoostingClassifier(n_estimators= 50, max_features= 2, max_depth= 5, learning_rate= 0.075)
gbc.fit(X_train, y_train)

y_pr=gbc.predict(X_test)
print("Test set accuracy: {:.3f}".format(accuracy_score(y_test, y_pr)))

confusion_matrix(y_test, y_pr)
# Out:
# Test set accuracy: 0.877
# array([[90, 10],
#        [ 9, 45]], dtype=int64)

# %%
pip install keras
# Out:
# Requirement already satisfied: keras in c:\users\saket.garodia\anaconda3\lib\site-packages (2.4.3)
# Requirement already satisfied: pyyaml in c:\users\saket.garodia\anaconda3\lib\site-packages (from keras) (5.3.1)
# Requirement already satisfied: scipy>=0.14 in c:\users\saket.garodia\anaconda3\lib\site-packages (from keras) (1.5.0)
# Requirement already satisfied: h5py in c:\users\saket.garodia\anaconda3\lib\site-packages (from keras) (2.10.0)
# Requirement already satisfied: numpy>=1.9.1 in c:\users\saket.garodia\anaconda3\lib\site-packages (from keras) (1.19.5)
# Requirement already satisfied: six in c:\users\saket.garodia\anaconda3\lib\site-packages (from h5py->keras) (1.15.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\saket.garodia\anaconda3\lib\site-packages (2.4.1)
# Requirement already satisfied: astunparse~=1.6.3 in c:\users\saket.garodia\anaconda3\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: typing-extensions~=3.7.4 in c:\users\saket.garodia\anaconda3\lib\site-packages (from tensorflow) (3.7.4.2)
# Requirement already satisfied: numpy~=1.19.2 in c:\users\saket.garodia\anaconda3\lib\site-packages (from tensorflow) (1.19.5)
# Requirement already satisfied: flatbuffers~=1.12.0 in c:\users\saket.garodia\anaconda3\lib\site-packages (from tensorflow) (1.12)
# Requirement already satisfied: opt-einsum~=3.3.0 in c:\users\saket.garodia\anaconda3\lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: tensorboard~=2.4 in c:\users\saket.garodia\anaconda3\lib\site-packages (from tensorflow) (2.4.1)
# Requirement already satisfied: termcolor~=1.1.0 in c:\users\saket.garodia\anaconda3\lib\site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: h5py~=2.10.0 in c:\users\saket.garodia\anaconda3\lib\site-packages (from tensorflow) (2.10.0)
# Requirement already satisfied: google-pasta~=0.2 in c:\users\saket.garodia\anaconda3\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: six~=1.15.0 in c:\users\saket.garodia\anaconda3\lib\site-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: wheel~=0.35 in c:\users\saket.garodia\anaconda3\lib\site-packages (from tensorflow) (0.36.2)
# Requirement already satisfied: absl-py~=0.10 in c:\users\saket.garodia\anaconda3\lib\site-packages (from tensorflow) (0.12.0)
# Requirement already satisfied: wrapt~=1.12.1 in c:\users\saket.garodia\anaconda3\lib\site-packages (from tensorflow) (1.12.1)
# Requirement already satisfied: gast==0.3.3 in c:\users\saket.garodia\anaconda3\lib\site-packages (from tensorflow) (0.3.3)
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: protobuf>=3.9.2 in c:\users\saket.garodia\anaconda3\lib\site-packages (from tensorflow) (3.13.0)
# Requirement already satisfied: grpcio~=1.32.0 in c:\users\saket.garodia\anaconda3\lib\site-packages (from tensorflow) (1.32.0)
#
# Requirement already satisfied: keras-preprocessing~=1.1.2 in c:\users\saket.garodia\anaconda3\lib\site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: tensorflow-estimator<2.5.0,>=2.4.0 in c:\users\saket.garodia\anaconda3\lib\site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\saket.garodia\anaconda3\lib\site-packages (from tensorboard~=2.4->tensorflow) (54.1.1)
# Requirement already satisfied: google-auth<2,>=1.6.3 in c:\users\saket.garodia\anaconda3\lib\site-packages (from tensorboard~=2.4->tensorflow) (1.28.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\saket.garodia\anaconda3\lib\site-packages (from tensorboard~=2.4->tensorflow) (1.8.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\saket.garodia\anaconda3\lib\site-packages (from tensorboard~=2.4->tensorflow) (0.4.4)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\saket.garodia\anaconda3\lib\site-packages (from tensorboard~=2.4->tensorflow) (3.3.4)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\saket.garodia\anaconda3\lib\site-packages (from tensorboard~=2.4->tensorflow) (2.24.0)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\users\saket.garodia\anaconda3\lib\site-packages (from tensorboard~=2.4->tensorflow) (1.0.1)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\saket.garodia\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow) (4.2.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\saket.garodia\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.6" in c:\users\saket.garodia\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow) (4.7.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\saket.garodia\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.4->tensorflow) (1.3.0)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\saket.garodia\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\saket.garodia\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\saket.garodia\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\saket.garodia\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow) (1.25.9)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\saket.garodia\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\saket.garodia\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.4->tensorflow) (3.1.0)

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
def build_model():
    model = tf.keras.Sequential([
    tf.keras.layers.Dense(8, activation='relu', input_shape=[len(X_train.keys())]),
    #tf.keras.layers.Dense(4, activation='relu'),
    tf.keras.layers.Dense(4, activation='relu'),
    tf.keras.layers.Dense(2, activation='relu'),

    tf.keras.layers.Dense(1,activation='sigmoid')
  ])

    optimizer = tf.keras.optimizers.Adam(learning_rate=0.005, beta_1=0.9, beta_2=0.999, epsilon=1e-07)

    model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    return model

neural_model = build_model()

# %%
neural_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 8)                 72
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 36
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 10
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 3
# =================================================================
# Total params: 121
# Trainable params: 121
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import ModelCheckpoint

# %%
checkpoint_name = 'Weights\Weights-{epoch:03d}--{val_accuracy:.5f}.hdf5' 
checkpoint = ModelCheckpoint(checkpoint_name, monitor='val_loss', verbose = 1, save_best_only = False, mode ='auto')
callbacks_list = [checkpoint]

# %%
# Keeping EPOCHs high as dataset is small.
EPOCHS = 1000
neural_pred = neural_model.fit(X_train, y_train,epochs=EPOCHS, validation_split=0.15, verbose=2, callbacks = callbacks_list )
# Out:
# Epoch 1/1000
# 17/17 - 2s - loss: 0.9950 - accuracy: 0.3666 - val_loss: 0.7979 - val_accuracy: 0.3763
#
# Epoch 00001: saving model to Weights\Weights-001--0.37634.hdf5
# Epoch 2/1000
# 17/17 - 0s - loss: 0.6968 - accuracy: 0.5893 - val_loss: 0.6539 - val_accuracy: 0.7097
#
# Epoch 00002: saving model to Weights\Weights-002--0.70968.hdf5
# Epoch 3/1000
# 17/17 - 0s - loss: 0.6473 - accuracy: 0.7159 - val_loss: 0.6156 - val_accuracy: 0.7849
#
# Epoch 00003: saving model to Weights\Weights-003--0.78495.hdf5
# Epoch 4/1000
# 17/17 - 0s - loss: 0.6217 - accuracy: 0.7332 - val_loss: 0.5738 - val_accuracy: 0.8172
#
# Epoch 00004: saving model to Weights\Weights-004--0.81720.hdf5
# Epoch 5/1000
# 17/17 - 0s - loss: 0.5825 - accuracy: 0.7370 - val_loss: 0.5144 - val_accuracy: 0.8280
#
# Epoch 00005: saving model to Weights\Weights-005--0.82796.hdf5
# Epoch 6/1000
# 17/17 - 0s - loss: 0.5334 - accuracy: 0.7390 - val_loss: 0.4479 - val_accuracy: 0.7957
#
# Epoch 00006: saving model to Weights\Weights-006--0.79570.hdf5
# Epoch 7/1000
# 17/17 - 0s - loss: 0.4895 - accuracy: 0.7639 - val_loss: 0.4057 - val_accuracy: 0.7742
#
# Epoch 00007: saving model to Weights\Weights-007--0.77419.hdf5
# Epoch 8/1000
# 17/17 - 0s - loss: 0.4666 - accuracy: 0.7831 - val_loss: 0.3897 - val_accuracy: 0.7742
#
# Epoch 00008: saving model to Weights\Weights-008--0.77419.hdf5
# Epoch 9/1000
# 17/17 - 0s - loss: 0.4499 - accuracy: 0.7850 - val_loss: 0.3781 - val_accuracy: 0.7742
#
# Epoch 00009: saving model to Weights\Weights-009--0.77419.hdf5
# Epoch 10/1000
# 17/17 - 0s - loss: 0.4371 - accuracy: 0.7889 - val_loss: 0.3702 - val_accuracy: 0.7742
#
# Epoch 00010: saving model to Weights\Weights-010--0.77419.hdf5
# Epoch 11/1000
# 17/17 - 0s - loss: 0.4270 - accuracy: 0.7927 - val_loss: 0.3650 - val_accuracy: 0.7849
#
# Epoch 00011: saving model to Weights\Weights-011--0.78495.hdf5
# Epoch 12/1000
# 17/17 - 0s - loss: 0.4163 - accuracy: 0.8042 - val_loss: 0.3596 - val_accuracy: 0.8280
#
# Epoch 00012: saving model to Weights\Weights-012--0.82796.hdf5
# Epoch 13/1000
# 17/17 - 0s - loss: 0.4053 - accuracy: 0.8138 - val_loss: 0.3405 - val_accuracy: 0.8280
#
# Epoch 00013: saving model to Weights\Weights-013--0.82796.hdf5
# Epoch 14/1000
# 17/17 - 0s - loss: 0.3974 - accuracy: 0.8196 - val_loss: 0.3287 - val_accuracy: 0.8280
#
# Epoch 00014: saving model to Weights\Weights-014--0.82796.hdf5
# Epoch 15/1000
# 17/17 - 0s - loss: 0.3880 - accuracy: 0.8253 - val_loss: 0.3309 - val_accuracy: 0.8280
#
# Epoch 00015: saving model to Weights\Weights-015--0.82796.hdf5
# Epoch 16/1000
# 17/17 - 0s - loss: 0.3790 - accuracy: 0.8407 - val_loss: 0.3159 - val_accuracy: 0.8387
#
# Epoch 00016: saving model to Weights\Weights-016--0.83871.hdf5
# Epoch 17/1000
# 17/17 - 0s - loss: 0.3728 - accuracy: 0.8522 - val_loss: 0.3146 - val_accuracy: 0.8387
#
# Epoch 00017: saving model to Weights\Weights-017--0.83871.hdf5
# Epoch 18/1000
# 17/17 - 0s - loss: 0.3666 - accuracy: 0.8599 - val_loss: 0.2986 - val_accuracy: 0.8387
#
# Epoch 00018: saving model to Weights\Weights-018--0.83871.hdf5
# Epoch 19/1000
# 17/17 - 0s - loss: 0.3613 - accuracy: 0.8580 - val_loss: 0.2952 - val_accuracy: 0.8602
#
# Epoch 00019: saving model to Weights\Weights-019--0.86022.hdf5
# Epoch 20/1000
# 17/17 - 0s - loss: 0.3520 - accuracy: 0.8599 - val_loss: 0.2900 - val_accuracy: 0.8602
#
# Epoch 00020: saving model to Weights\Weights-020--0.86022.hdf5
# Epoch 21/1000
# 17/17 - 0s - loss: 0.3506 - accuracy: 0.8599 - val_loss: 0.2888 - val_accuracy: 0.8710
#
# Epoch 00021: saving model to Weights\Weights-021--0.87097.hdf5
# Epoch 22/1000
# 17/17 - 0s - loss: 0.3449 - accuracy: 0.8560 - val_loss: 0.2778 - val_accuracy: 0.8710
#
# Epoch 00022: saving model to Weights\Weights-022--0.87097.hdf5
# Epoch 23/1000
# 17/17 - 0s - loss: 0.3417 - accuracy: 0.8618 - val_loss: 0.2831 - val_accuracy: 0.8602
#
# Epoch 00023: saving model to Weights\Weights-023--0.86022.hdf5
# Epoch 24/1000
# 17/17 - 0s - loss: 0.3357 - accuracy: 0.8733 - val_loss: 0.2799 - val_accuracy: 0.8710
#
# Epoch 00024: saving model to Weights\Weights-024--0.87097.hdf5
# Epoch 25/1000
# 17/17 - 0s - loss: 0.3350 - accuracy: 0.8656 - val_loss: 0.2592 - val_accuracy: 0.8817
#
# Epoch 00025: saving model to Weights\Weights-025--0.88172.hdf5
# Epoch 26/1000
# 17/17 - 0s - loss: 0.3314 - accuracy: 0.8695 - val_loss: 0.2708 - val_accuracy: 0.8817
#
# Epoch 00026: saving model to Weights\Weights-026--0.88172.hdf5
# Epoch 27/1000
# 17/17 - 0s - loss: 0.3308 - accuracy: 0.8637 - val_loss: 0.2753 - val_accuracy: 0.8710
#
# Epoch 00027: saving model to Weights\Weights-027--0.87097.hdf5
# Epoch 28/1000
# 17/17 - 0s - loss: 0.3293 - accuracy: 0.8695 - val_loss: 0.2654 - val_accuracy: 0.8817
#
# Epoch 00028: saving model to Weights\Weights-028--0.88172.hdf5
# Epoch 29/1000
# 17/17 - 0s - loss: 0.3218 - accuracy: 0.8695 - val_loss: 0.2615 - val_accuracy: 0.8817
#
# Epoch 00029: saving model to Weights\Weights-029--0.88172.hdf5
# Epoch 30/1000
# 17/17 - 0s - loss: 0.3221 - accuracy: 0.8714 - val_loss: 0.2601 - val_accuracy: 0.8710
#
# Epoch 00030: saving model to Weights\Weights-030--0.87097.hdf5
# Epoch 31/1000
# 17/17 - 0s - loss: 0.3181 - accuracy: 0.8714 - val_loss: 0.2557 - val_accuracy: 0.8817
#
# Epoch 00031: saving model to Weights\Weights-031--0.88172.hdf5
# Epoch 32/1000
# 17/17 - 0s - loss: 0.3196 - accuracy: 0.8733 - val_loss: 0.2479 - val_accuracy: 0.8817
#
# Epoch 00032: saving model to Weights\Weights-032--0.88172.hdf5
# Epoch 33/1000
# 17/17 - 0s - loss: 0.3162 - accuracy: 0.8733 - val_loss: 0.2473 - val_accuracy: 0.8817
#
# Epoch 00033: saving model to Weights\Weights-033--0.88172.hdf5
# Epoch 34/1000
# 17/17 - 0s - loss: 0.3134 - accuracy: 0.8733 - val_loss: 0.2542 - val_accuracy: 0.8710
#
# Epoch 00034: saving model to Weights\Weights-034--0.87097.hdf5
# Epoch 35/1000
# 17/17 - 0s - loss: 0.3126 - accuracy: 0.8752 - val_loss: 0.2518 - val_accuracy: 0.8710
#
# Epoch 00035: saving model to Weights\Weights-035--0.87097.hdf5
# Epoch 36/1000
# 17/17 - 0s - loss: 0.3109 - accuracy: 0.8772 - val_loss: 0.2574 - val_accuracy: 0.8710
#
# Epoch 00036: saving model to Weights\Weights-036--0.87097.hdf5
# Epoch 37/1000
# 17/17 - 0s - loss: 0.3108 - accuracy: 0.8752 - val_loss: 0.2444 - val_accuracy: 0.8817
#
# Epoch 00037: saving model to Weights\Weights-037--0.88172.hdf5
# Epoch 38/1000
# 17/17 - 0s - loss: 0.3075 - accuracy: 0.8810 - val_loss: 0.2457 - val_accuracy: 0.8710
#
# Epoch 00038: saving model to Weights\Weights-038--0.87097.hdf5
# Epoch 39/1000
# 17/17 - 0s - loss: 0.3036 - accuracy: 0.8791 - val_loss: 0.2397 - val_accuracy: 0.8817
#
# Epoch 00039: saving model to Weights\Weights-039--0.88172.hdf5
# Epoch 40/1000
# 17/17 - 0s - loss: 0.3023 - accuracy: 0.8810 - val_loss: 0.2429 - val_accuracy: 0.8817
#
# Epoch 00040: saving model to Weights\Weights-040--0.88172.hdf5
# Epoch 41/1000
# 17/17 - 0s - loss: 0.2992 - accuracy: 0.8791 - val_loss: 0.2460 - val_accuracy: 0.8817
#
# Epoch 00041: saving model to Weights\Weights-041--0.88172.hdf5
# Epoch 42/1000
# 17/17 - 0s - loss: 0.2976 - accuracy: 0.8829 - val_loss: 0.2360 - val_accuracy: 0.8925
#
# Epoch 00042: saving model to Weights\Weights-042--0.89247.hdf5
# Epoch 43/1000
# 17/17 - 0s - loss: 0.2930 - accuracy: 0.8829 - val_loss: 0.2405 - val_accuracy: 0.8925
#
# Epoch 00043: saving model to Weights\Weights-043--0.89247.hdf5
# Epoch 44/1000
# 17/17 - 0s - loss: 0.2954 - accuracy: 0.8733 - val_loss: 0.2377 - val_accuracy: 0.8925
#
# Epoch 00044: saving model to Weights\Weights-044--0.89247.hdf5
# Epoch 45/1000
# 17/17 - 0s - loss: 0.2939 - accuracy: 0.8791 - val_loss: 0.2410 - val_accuracy: 0.8925
#
# Epoch 00045: saving model to Weights\Weights-045--0.89247.hdf5
# Epoch 46/1000
# 17/17 - 0s - loss: 0.2932 - accuracy: 0.8791 - val_loss: 0.2428 - val_accuracy: 0.8925
#
# Epoch 00046: saving model to Weights\Weights-046--0.89247.hdf5
# Epoch 47/1000
# 17/17 - 0s - loss: 0.2920 - accuracy: 0.8810 - val_loss: 0.2350 - val_accuracy: 0.9032
#
# Epoch 00047: saving model to Weights\Weights-047--0.90323.hdf5
# Epoch 48/1000
# 17/17 - 0s - loss: 0.2896 - accuracy: 0.8772 - val_loss: 0.2354 - val_accuracy: 0.8925
#
# Epoch 00048: saving model to Weights\Weights-048--0.89247.hdf5
# Epoch 49/1000
# 17/17 - 0s - loss: 0.2871 - accuracy: 0.8810 - val_loss: 0.2287 - val_accuracy: 0.9032
#
# Epoch 00049: saving model to Weights\Weights-049--0.90323.hdf5
# Epoch 50/1000
# 17/17 - 0s - loss: 0.2864 - accuracy: 0.8791 - val_loss: 0.2342 - val_accuracy: 0.8925
#
# Epoch 00050: saving model to Weights\Weights-050--0.89247.hdf5
# Epoch 51/1000
# 17/17 - 0s - loss: 0.2832 - accuracy: 0.8829 - val_loss: 0.2276 - val_accuracy: 0.8925
#
# Epoch 00051: saving model to Weights\Weights-051--0.89247.hdf5
# Epoch 52/1000
# 17/17 - 0s - loss: 0.2863 - accuracy: 0.8829 - val_loss: 0.2286 - val_accuracy: 0.8925
#
# Epoch 00052: saving model to Weights\Weights-052--0.89247.hdf5
# Epoch 53/1000
# 17/17 - 0s - loss: 0.2833 - accuracy: 0.8810 - val_loss: 0.2248 - val_accuracy: 0.9032
#
# Epoch 00053: saving model to Weights\Weights-053--0.90323.hdf5
# Epoch 54/1000
# 17/17 - 0s - loss: 0.2807 - accuracy: 0.8791 - val_loss: 0.2367 - val_accuracy: 0.8925
#
# Epoch 00054: saving model to Weights\Weights-054--0.89247.hdf5
# Epoch 55/1000
# 17/17 - 0s - loss: 0.2810 - accuracy: 0.8887 - val_loss: 0.2286 - val_accuracy: 0.8925
#
# Epoch 00055: saving model to Weights\Weights-055--0.89247.hdf5
# Epoch 56/1000
# 17/17 - 0s - loss: 0.2840 - accuracy: 0.8848 - val_loss: 0.2337 - val_accuracy: 0.8925
#
# Epoch 00056: saving model to Weights\Weights-056--0.89247.hdf5
# Epoch 57/1000
# 17/17 - 0s - loss: 0.2792 - accuracy: 0.8829 - val_loss: 0.2238 - val_accuracy: 0.8925
#
# Epoch 00057: saving model to Weights\Weights-057--0.89247.hdf5
# Epoch 58/1000
# 17/17 - 0s - loss: 0.2805 - accuracy: 0.8906 - val_loss: 0.2370 - val_accuracy: 0.8925
#
# Epoch 00058: saving model to Weights\Weights-058--0.89247.hdf5
# Epoch 59/1000
# 17/17 - 0s - loss: 0.2781 - accuracy: 0.8772 - val_loss: 0.2307 - val_accuracy: 0.9032
#
# Epoch 00059: saving model to Weights\Weights-059--0.90323.hdf5
# Epoch 60/1000
# 17/17 - 0s - loss: 0.2794 - accuracy: 0.8848 - val_loss: 0.2449 - val_accuracy: 0.8710
#
# Epoch 00060: saving model to Weights\Weights-060--0.87097.hdf5
# Epoch 61/1000
# 17/17 - 0s - loss: 0.2762 - accuracy: 0.8848 - val_loss: 0.2388 - val_accuracy: 0.8710
#
# Epoch 00061: saving model to Weights\Weights-061--0.87097.hdf5
# Epoch 62/1000
# 17/17 - 0s - loss: 0.2728 - accuracy: 0.8848 - val_loss: 0.2265 - val_accuracy: 0.9032
#
# Epoch 00062: saving model to Weights\Weights-062--0.90323.hdf5
# Epoch 63/1000
# 17/17 - 0s - loss: 0.2721 - accuracy: 0.8829 - val_loss: 0.2337 - val_accuracy: 0.8925
#
# Epoch 00063: saving model to Weights\Weights-063--0.89247.hdf5
# Epoch 64/1000
# 17/17 - 0s - loss: 0.2724 - accuracy: 0.8868 - val_loss: 0.2291 - val_accuracy: 0.9032
#
# Epoch 00064: saving model to Weights\Weights-064--0.90323.hdf5
# Epoch 65/1000
# 17/17 - 0s - loss: 0.2685 - accuracy: 0.8887 - val_loss: 0.2414 - val_accuracy: 0.8817
#
# Epoch 00065: saving model to Weights\Weights-065--0.88172.hdf5
# Epoch 66/1000
# 17/17 - 0s - loss: 0.2690 - accuracy: 0.8887 - val_loss: 0.2387 - val_accuracy: 0.8925
#
# Epoch 00066: saving model to Weights\Weights-066--0.89247.hdf5
# Epoch 67/1000
# 17/17 - 0s - loss: 0.2690 - accuracy: 0.8887 - val_loss: 0.2536 - val_accuracy: 0.8817
#
# Epoch 00067: saving model to Weights\Weights-067--0.88172.hdf5
# Epoch 68/1000
# 17/17 - 0s - loss: 0.2643 - accuracy: 0.8944 - val_loss: 0.2360 - val_accuracy: 0.9032
#
# Epoch 00068: saving model to Weights\Weights-068--0.90323.hdf5
# Epoch 69/1000
# 17/17 - 0s - loss: 0.2705 - accuracy: 0.8944 - val_loss: 0.2489 - val_accuracy: 0.8710
#
# Epoch 00069: saving model to Weights\Weights-069--0.87097.hdf5
# Epoch 70/1000
# 17/17 - 0s - loss: 0.2681 - accuracy: 0.8944 - val_loss: 0.2434 - val_accuracy: 0.8817
#
# Epoch 00070: saving model to Weights\Weights-070--0.88172.hdf5
# Epoch 71/1000
# 17/17 - 0s - loss: 0.2663 - accuracy: 0.8887 - val_loss: 0.2559 - val_accuracy: 0.8710
#
# Epoch 00071: saving model to Weights\Weights-071--0.87097.hdf5
# Epoch 72/1000
# 17/17 - 0s - loss: 0.2598 - accuracy: 0.8983 - val_loss: 0.2413 - val_accuracy: 0.8817
#
# Epoch 00072: saving model to Weights\Weights-072--0.88172.hdf5
# Epoch 73/1000
# 17/17 - 0s - loss: 0.2618 - accuracy: 0.8887 - val_loss: 0.2464 - val_accuracy: 0.8925
#
# Epoch 00073: saving model to Weights\Weights-073--0.89247.hdf5
# Epoch 74/1000
# 17/17 - 0s - loss: 0.2646 - accuracy: 0.8944 - val_loss: 0.2365 - val_accuracy: 0.8925
#
# Epoch 00074: saving model to Weights\Weights-074--0.89247.hdf5
# Epoch 75/1000
# 17/17 - 0s - loss: 0.2567 - accuracy: 0.9021 - val_loss: 0.2805 - val_accuracy: 0.8710
#
# Epoch 00075: saving model to Weights\Weights-075--0.87097.hdf5
# Epoch 76/1000
# 17/17 - 0s - loss: 0.2559 - accuracy: 0.8906 - val_loss: 0.2503 - val_accuracy: 0.8817
#
# Epoch 00076: saving model to Weights\Weights-076--0.88172.hdf5
# Epoch 77/1000
# 17/17 - 0s - loss: 0.2584 - accuracy: 0.9079 - val_loss: 0.2778 - val_accuracy: 0.8710
#
# Epoch 00077: saving model to Weights\Weights-077--0.87097.hdf5
# Epoch 78/1000
# 17/17 - 0s - loss: 0.2536 - accuracy: 0.9002 - val_loss: 0.2727 - val_accuracy: 0.8710
#
# Epoch 00078: saving model to Weights\Weights-078--0.87097.hdf5
# Epoch 79/1000
# 17/17 - 0s - loss: 0.2503 - accuracy: 0.9021 - val_loss: 0.2640 - val_accuracy: 0.8817
#
# Epoch 00079: saving model to Weights\Weights-079--0.88172.hdf5
# Epoch 80/1000
# 17/17 - 0s - loss: 0.2476 - accuracy: 0.9040 - val_loss: 0.2733 - val_accuracy: 0.8710
#
# Epoch 00080: saving model to Weights\Weights-080--0.87097.hdf5
# Epoch 81/1000
# 17/17 - 0s - loss: 0.2482 - accuracy: 0.9040 - val_loss: 0.2686 - val_accuracy: 0.8710
#
# Epoch 00081: saving model to Weights\Weights-081--0.87097.hdf5
# Epoch 82/1000
# 17/17 - 0s - loss: 0.2463 - accuracy: 0.9060 - val_loss: 0.2658 - val_accuracy: 0.8817
#
# Epoch 00082: saving model to Weights\Weights-082--0.88172.hdf5
# Epoch 83/1000
# 17/17 - 0s - loss: 0.2446 - accuracy: 0.9021 - val_loss: 0.2695 - val_accuracy: 0.8710
#
# Epoch 00083: saving model to Weights\Weights-083--0.87097.hdf5
# Epoch 84/1000
# 17/17 - 0s - loss: 0.2447 - accuracy: 0.9040 - val_loss: 0.2730 - val_accuracy: 0.8710
#
# Epoch 00084: saving model to Weights\Weights-084--0.87097.hdf5
# Epoch 85/1000
# 17/17 - 0s - loss: 0.2481 - accuracy: 0.8983 - val_loss: 0.2797 - val_accuracy: 0.8817
#
# Epoch 00085: saving model to Weights\Weights-085--0.88172.hdf5
# Epoch 86/1000
# 17/17 - 0s - loss: 0.2477 - accuracy: 0.9098 - val_loss: 0.2992 - val_accuracy: 0.8710
#
# Epoch 00086: saving model to Weights\Weights-086--0.87097.hdf5
# Epoch 87/1000
# 17/17 - 0s - loss: 0.2518 - accuracy: 0.9002 - val_loss: 0.2864 - val_accuracy: 0.8817
#
# Epoch 00087: saving model to Weights\Weights-087--0.88172.hdf5
# Epoch 88/1000
# 17/17 - 0s - loss: 0.2397 - accuracy: 0.9117 - val_loss: 0.3086 - val_accuracy: 0.8710
#
# Epoch 00088: saving model to Weights\Weights-088--0.87097.hdf5
# Epoch 89/1000
# 17/17 - 0s - loss: 0.2397 - accuracy: 0.9098 - val_loss: 0.2911 - val_accuracy: 0.8710
#
# Epoch 00089: saving model to Weights\Weights-089--0.87097.hdf5
# Epoch 90/1000
# 17/17 - 0s - loss: 0.2380 - accuracy: 0.9060 - val_loss: 0.2892 - val_accuracy: 0.8817
#
# Epoch 00090: saving model to Weights\Weights-090--0.88172.hdf5
# Epoch 91/1000
# 17/17 - 0s - loss: 0.2399 - accuracy: 0.9040 - val_loss: 0.3023 - val_accuracy: 0.8710
#
# Epoch 00091: saving model to Weights\Weights-091--0.87097.hdf5
# Epoch 92/1000
# 17/17 - 0s - loss: 0.2398 - accuracy: 0.9021 - val_loss: 0.2910 - val_accuracy: 0.8817
#
# Epoch 00092: saving model to Weights\Weights-092--0.88172.hdf5
# Epoch 93/1000
# 17/17 - 0s - loss: 0.2349 - accuracy: 0.9098 - val_loss: 0.3015 - val_accuracy: 0.8817
#
# Epoch 00093: saving model to Weights\Weights-093--0.88172.hdf5
# Epoch 94/1000
# 17/17 - 0s - loss: 0.2404 - accuracy: 0.9021 - val_loss: 0.2762 - val_accuracy: 0.8817
#
# Epoch 00094: saving model to Weights\Weights-094--0.88172.hdf5
# Epoch 95/1000
# 17/17 - 0s - loss: 0.2351 - accuracy: 0.9021 - val_loss: 0.3082 - val_accuracy: 0.8710
#
# Epoch 00095: saving model to Weights\Weights-095--0.87097.hdf5
# Epoch 96/1000
# 17/17 - 0s - loss: 0.2349 - accuracy: 0.9060 - val_loss: 0.2916 - val_accuracy: 0.8925
#
# Epoch 00096: saving model to Weights\Weights-096--0.89247.hdf5
# Epoch 97/1000
# 17/17 - 0s - loss: 0.2346 - accuracy: 0.9060 - val_loss: 0.2957 - val_accuracy: 0.8710
#
# Epoch 00097: saving model to Weights\Weights-097--0.87097.hdf5
# Epoch 98/1000
# 17/17 - 0s - loss: 0.2320 - accuracy: 0.9021 - val_loss: 0.2955 - val_accuracy: 0.8817
#
# Epoch 00098: saving model to Weights\Weights-098--0.88172.hdf5
# Epoch 99/1000
# 17/17 - 0s - loss: 0.2320 - accuracy: 0.9079 - val_loss: 0.3255 - val_accuracy: 0.8817
#
# Epoch 00099: saving model to Weights\Weights-099--0.88172.hdf5
# Epoch 100/1000
# 17/17 - 0s - loss: 0.2351 - accuracy: 0.9021 - val_loss: 0.3066 - val_accuracy: 0.8710
#
# Epoch 00100: saving model to Weights\Weights-100--0.87097.hdf5
# Epoch 101/1000
# 17/17 - 0s - loss: 0.2297 - accuracy: 0.9060 - val_loss: 0.3184 - val_accuracy: 0.8710
# Epoch 00101: saving model to Weights\Weights-101--0.87097.hdf5
# Epoch 102/1000
# 17/17 - 0s - loss: 0.2329 - accuracy: 0.9021 - val_loss: 0.3112 - val_accuracy: 0.8710
#
# Epoch 00102: saving model to Weights\Weights-102--0.87097.hdf5
# Epoch 103/1000
# 17/17 - 0s - loss: 0.2296 - accuracy: 0.9040 - val_loss: 0.3125 - val_accuracy: 0.8602
#
# Epoch 00103: saving model to Weights\Weights-103--0.86022.hdf5
# Epoch 104/1000
# 17/17 - 0s - loss: 0.2308 - accuracy: 0.9060 - val_loss: 0.3264 - val_accuracy: 0.8710
#
# Epoch 00104: saving model to Weights\Weights-104--0.87097.hdf5
# Epoch 105/1000
# 17/17 - 0s - loss: 0.2303 - accuracy: 0.9021 - val_loss: 0.3086 - val_accuracy: 0.8710
#
# Epoch 00105: saving model to Weights\Weights-105--0.87097.hdf5
# Epoch 106/1000
# 17/17 - 0s - loss: 0.2460 - accuracy: 0.9002 - val_loss: 0.3285 - val_accuracy: 0.8602
#
# Epoch 00106: saving model to Weights\Weights-106--0.86022.hdf5
# Epoch 107/1000
# 17/17 - 0s - loss: 0.2345 - accuracy: 0.9002 - val_loss: 0.3114 - val_accuracy: 0.8495
#
# Epoch 00107: saving model to Weights\Weights-107--0.84946.hdf5
# Epoch 108/1000
# 17/17 - 0s - loss: 0.2288 - accuracy: 0.9060 - val_loss: 0.3131 - val_accuracy: 0.8710
#
# Epoch 00108: saving model to Weights\Weights-108--0.87097.hdf5
# Epoch 109/1000
# 17/17 - 0s - loss: 0.2243 - accuracy: 0.9098 - val_loss: 0.3071 - val_accuracy: 0.8602
#
# Epoch 00109: saving model to Weights\Weights-109--0.86022.hdf5
# Epoch 110/1000
# 17/17 - 0s - loss: 0.2250 - accuracy: 0.9098 - val_loss: 0.3355 - val_accuracy: 0.8817
#
# Epoch 00110: saving model to Weights\Weights-110--0.88172.hdf5
# Epoch 111/1000
# 17/17 - 0s - loss: 0.2257 - accuracy: 0.9098 - val_loss: 0.3202 - val_accuracy: 0.8495
#
# Epoch 00111: saving model to Weights\Weights-111--0.84946.hdf5
# Epoch 112/1000
# 17/17 - 0s - loss: 0.2195 - accuracy: 0.9117 - val_loss: 0.3207 - val_accuracy: 0.8710
#
# Epoch 00112: saving model to Weights\Weights-112--0.87097.hdf5
# Epoch 113/1000
# 17/17 - 0s - loss: 0.2216 - accuracy: 0.9098 - val_loss: 0.3127 - val_accuracy: 0.8602
#
# Epoch 00113: saving model to Weights\Weights-113--0.86022.hdf5
# Epoch 114/1000
# 17/17 - 0s - loss: 0.2206 - accuracy: 0.9060 - val_loss: 0.3321 - val_accuracy: 0.8710
#
# Epoch 00114: saving model to Weights\Weights-114--0.87097.hdf5
# Epoch 115/1000
# 17/17 - 0s - loss: 0.2223 - accuracy: 0.9098 - val_loss: 0.3185 - val_accuracy: 0.8817
#
# Epoch 00115: saving model to Weights\Weights-115--0.88172.hdf5
# Epoch 116/1000
# 17/17 - 0s - loss: 0.2250 - accuracy: 0.9098 - val_loss: 0.3323 - val_accuracy: 0.8710
#
# Epoch 00116: saving model to Weights\Weights-116--0.87097.hdf5
# Epoch 117/1000
# 17/17 - 0s - loss: 0.2203 - accuracy: 0.9060 - val_loss: 0.3332 - val_accuracy: 0.8710
#
# Epoch 00117: saving model to Weights\Weights-117--0.87097.hdf5
# Epoch 118/1000
# 17/17 - 0s - loss: 0.2282 - accuracy: 0.9079 - val_loss: 0.3032 - val_accuracy: 0.8710
#
# Epoch 00118: saving model to Weights\Weights-118--0.87097.hdf5
# Epoch 119/1000
# 17/17 - 0s - loss: 0.2296 - accuracy: 0.9040 - val_loss: 0.3448 - val_accuracy: 0.8710
#
# Epoch 00119: saving model to Weights\Weights-119--0.87097.hdf5
# Epoch 120/1000
# 17/17 - 0s - loss: 0.2300 - accuracy: 0.9098 - val_loss: 0.3344 - val_accuracy: 0.8817
#
# Epoch 00120: saving model to Weights\Weights-120--0.88172.hdf5
# Epoch 121/1000
# 17/17 - 0s - loss: 0.2181 - accuracy: 0.9175 - val_loss: 0.3214 - val_accuracy: 0.8602
#
# Epoch 00121: saving model to Weights\Weights-121--0.86022.hdf5
# Epoch 122/1000
# 17/17 - 0s - loss: 0.2141 - accuracy: 0.9117 - val_loss: 0.3225 - val_accuracy: 0.8602
#
# Epoch 00122: saving model to Weights\Weights-122--0.86022.hdf5
# Epoch 123/1000
# 17/17 - 0s - loss: 0.2247 - accuracy: 0.9117 - val_loss: 0.3456 - val_accuracy: 0.8710
#
# Epoch 00123: saving model to Weights\Weights-123--0.87097.hdf5
# Epoch 124/1000
# 17/17 - 0s - loss: 0.2184 - accuracy: 0.9079 - val_loss: 0.3028 - val_accuracy: 0.8710
#
# Epoch 00124: saving model to Weights\Weights-124--0.87097.hdf5
# Epoch 125/1000
# 17/17 - 0s - loss: 0.2205 - accuracy: 0.9079 - val_loss: 0.3178 - val_accuracy: 0.8602
#
# Epoch 00125: saving model to Weights\Weights-125--0.86022.hdf5
# Epoch 126/1000
# 17/17 - 0s - loss: 0.2190 - accuracy: 0.9117 - val_loss: 0.3298 - val_accuracy: 0.8817
#
# Epoch 00126: saving model to Weights\Weights-126--0.88172.hdf5
# Epoch 127/1000
# 17/17 - 0s - loss: 0.2178 - accuracy: 0.9040 - val_loss: 0.3360 - val_accuracy: 0.8602
#
# Epoch 00127: saving model to Weights\Weights-127--0.86022.hdf5
# Epoch 128/1000
# 17/17 - 0s - loss: 0.2181 - accuracy: 0.9136 - val_loss: 0.3274 - val_accuracy: 0.8817
#
# Epoch 00128: saving model to Weights\Weights-128--0.88172.hdf5
# Epoch 129/1000
# 17/17 - 0s - loss: 0.2152 - accuracy: 0.9098 - val_loss: 0.3390 - val_accuracy: 0.8710
#
# Epoch 00129: saving model to Weights\Weights-129--0.87097.hdf5
# Epoch 130/1000
# 17/17 - 0s - loss: 0.2185 - accuracy: 0.9098 - val_loss: 0.3233 - val_accuracy: 0.8710
#
# Epoch 00130: saving model to Weights\Weights-130--0.87097.hdf5
# Epoch 131/1000
# 17/17 - 0s - loss: 0.2151 - accuracy: 0.9155 - val_loss: 0.3597 - val_accuracy: 0.8710
#
# Epoch 00131: saving model to Weights\Weights-131--0.87097.hdf5
# Epoch 132/1000
# 17/17 - 0s - loss: 0.2158 - accuracy: 0.9098 - val_loss: 0.3323 - val_accuracy: 0.8710
#
# Epoch 00132: saving model to Weights\Weights-132--0.87097.hdf5
# Epoch 133/1000
# 17/17 - 0s - loss: 0.2151 - accuracy: 0.9155 - val_loss: 0.3323 - val_accuracy: 0.8495
#
# Epoch 00133: saving model to Weights\Weights-133--0.84946.hdf5
# Epoch 134/1000
# 17/17 - 0s - loss: 0.2225 - accuracy: 0.9060 - val_loss: 0.3655 - val_accuracy: 0.8602
#
# Epoch 00134: saving model to Weights\Weights-134--0.86022.hdf5
# Epoch 135/1000
# 17/17 - 0s - loss: 0.2150 - accuracy: 0.9117 - val_loss: 0.3229 - val_accuracy: 0.8817
#
# Epoch 00135: saving model to Weights\Weights-135--0.88172.hdf5
# Epoch 136/1000
# 17/17 - 0s - loss: 0.2258 - accuracy: 0.9079 - val_loss: 0.3550 - val_accuracy: 0.8817
#
# Epoch 00136: saving model to Weights\Weights-136--0.88172.hdf5
# Epoch 137/1000
# 17/17 - 0s - loss: 0.2152 - accuracy: 0.9136 - val_loss: 0.3447 - val_accuracy: 0.8710
#
# Epoch 00137: saving model to Weights\Weights-137--0.87097.hdf5
# Epoch 138/1000
# 17/17 - 0s - loss: 0.2144 - accuracy: 0.9136 - val_loss: 0.3336 - val_accuracy: 0.8710
#
# Epoch 00138: saving model to Weights\Weights-138--0.87097.hdf5
# Epoch 139/1000
# 17/17 - 0s - loss: 0.2124 - accuracy: 0.9136 - val_loss: 0.3455 - val_accuracy: 0.8817
#
# Epoch 00139: saving model to Weights\Weights-139--0.88172.hdf5
# Epoch 140/1000
# 17/17 - 0s - loss: 0.2186 - accuracy: 0.9155 - val_loss: 0.3552 - val_accuracy: 0.8602
#
# Epoch 00140: saving model to Weights\Weights-140--0.86022.hdf5
# Epoch 141/1000
# 17/17 - 0s - loss: 0.2143 - accuracy: 0.9136 - val_loss: 0.3373 - val_accuracy: 0.8817
#
# Epoch 00141: saving model to Weights\Weights-141--0.88172.hdf5
# Epoch 142/1000
# 17/17 - 0s - loss: 0.2189 - accuracy: 0.9079 - val_loss: 0.3531 - val_accuracy: 0.8602
#
# Epoch 00142: saving model to Weights\Weights-142--0.86022.hdf5
# Epoch 143/1000
# 17/17 - 0s - loss: 0.2124 - accuracy: 0.9175 - val_loss: 0.3422 - val_accuracy: 0.8817
#
# Epoch 00143: saving model to Weights\Weights-143--0.88172.hdf5
# Epoch 144/1000
# 17/17 - 0s - loss: 0.2125 - accuracy: 0.9175 - val_loss: 0.3463 - val_accuracy: 0.8817
#
# Epoch 00144: saving model to Weights\Weights-144--0.88172.hdf5
# Epoch 145/1000
# 17/17 - 0s - loss: 0.2115 - accuracy: 0.9194 - val_loss: 0.3555 - val_accuracy: 0.8710
#
# Epoch 00145: saving model to Weights\Weights-145--0.87097.hdf5
# Epoch 146/1000
# 17/17 - 0s - loss: 0.2102 - accuracy: 0.9136 - val_loss: 0.3512 - val_accuracy: 0.8817
#
# Epoch 00146: saving model to Weights\Weights-146--0.88172.hdf5
# Epoch 147/1000
# 17/17 - 0s - loss: 0.2131 - accuracy: 0.9155 - val_loss: 0.3636 - val_accuracy: 0.8602
#
# Epoch 00147: saving model to Weights\Weights-147--0.86022.hdf5
# Epoch 148/1000
# 17/17 - 0s - loss: 0.2122 - accuracy: 0.9175 - val_loss: 0.3390 - val_accuracy: 0.8817
#
# Epoch 00148: saving model to Weights\Weights-148--0.88172.hdf5
# Epoch 149/1000
# 17/17 - 0s - loss: 0.2115 - accuracy: 0.9175 - val_loss: 0.3603 - val_accuracy: 0.8602
#
# Epoch 00149: saving model to Weights\Weights-149--0.86022.hdf5
# Epoch 150/1000
# 17/17 - 0s - loss: 0.2096 - accuracy: 0.9175 - val_loss: 0.3651 - val_accuracy: 0.8710
#
# Epoch 00150: saving model to Weights\Weights-150--0.87097.hdf5
# Epoch 151/1000
# 17/17 - 0s - loss: 0.2063 - accuracy: 0.9175 - val_loss: 0.3448 - val_accuracy: 0.8817
#
# Epoch 00151: saving model to Weights\Weights-151--0.88172.hdf5
# Epoch 152/1000
# 17/17 - 0s - loss: 0.2091 - accuracy: 0.9194 - val_loss: 0.3875 - val_accuracy: 0.8495
#
# Epoch 00152: saving model to Weights\Weights-152--0.84946.hdf5
# Epoch 153/1000
# 17/17 - 0s - loss: 0.2074 - accuracy: 0.9175 - val_loss: 0.3431 - val_accuracy: 0.8817
#
# Epoch 00153: saving model to Weights\Weights-153--0.88172.hdf5
# Epoch 154/1000
# 17/17 - 0s - loss: 0.2117 - accuracy: 0.9117 - val_loss: 0.3917 - val_accuracy: 0.8495
#
# Epoch 00154: saving model to Weights\Weights-154--0.84946.hdf5
# Epoch 155/1000
# 17/17 - 0s - loss: 0.2072 - accuracy: 0.9155 - val_loss: 0.3512 - val_accuracy: 0.8817
#
# Epoch 00155: saving model to Weights\Weights-155--0.88172.hdf5
# Epoch 156/1000
# 17/17 - 0s - loss: 0.2132 - accuracy: 0.9175 - val_loss: 0.3857 - val_accuracy: 0.8602
#
# Epoch 00156: saving model to Weights\Weights-156--0.86022.hdf5
# Epoch 157/1000
# 17/17 - 0s - loss: 0.2206 - accuracy: 0.9175 - val_loss: 0.3326 - val_accuracy: 0.8817
#
# Epoch 00157: saving model to Weights\Weights-157--0.88172.hdf5
# Epoch 158/1000
# 17/17 - 0s - loss: 0.2217 - accuracy: 0.9060 - val_loss: 0.3985 - val_accuracy: 0.8495
#
# Epoch 00158: saving model to Weights\Weights-158--0.84946.hdf5
# Epoch 159/1000
# 17/17 - 0s - loss: 0.2136 - accuracy: 0.9194 - val_loss: 0.3663 - val_accuracy: 0.8817
#
# Epoch 00159: saving model to Weights\Weights-159--0.88172.hdf5
# Epoch 160/1000
# 17/17 - 0s - loss: 0.2137 - accuracy: 0.9155 - val_loss: 0.3733 - val_accuracy: 0.8495
#
# Epoch 00160: saving model to Weights\Weights-160--0.84946.hdf5
# Epoch 161/1000
# 17/17 - 0s - loss: 0.2109 - accuracy: 0.9155 - val_loss: 0.3663 - val_accuracy: 0.8710
#
# Epoch 00161: saving model to Weights\Weights-161--0.87097.hdf5
# Epoch 162/1000
# 17/17 - 0s - loss: 0.2138 - accuracy: 0.9136 - val_loss: 0.3597 - val_accuracy: 0.8710
#
# Epoch 00162: saving model to Weights\Weights-162--0.87097.hdf5
# Epoch 163/1000
# 17/17 - 0s - loss: 0.2068 - accuracy: 0.9175 - val_loss: 0.3903 - val_accuracy: 0.8495
#
# Epoch 00163: saving model to Weights\Weights-163--0.84946.hdf5
# Epoch 164/1000
# 17/17 - 0s - loss: 0.2189 - accuracy: 0.9117 - val_loss: 0.3734 - val_accuracy: 0.8495
#
# Epoch 00164: saving model to Weights\Weights-164--0.84946.hdf5
# Epoch 165/1000
# 17/17 - 0s - loss: 0.2129 - accuracy: 0.9155 - val_loss: 0.3574 - val_accuracy: 0.8710
#
# Epoch 00165: saving model to Weights\Weights-165--0.87097.hdf5
# Epoch 166/1000
# 17/17 - 0s - loss: 0.2086 - accuracy: 0.9194 - val_loss: 0.3683 - val_accuracy: 0.8817
#
# Epoch 00166: saving model to Weights\Weights-166--0.88172.hdf5
# Epoch 167/1000
# 17/17 - 0s - loss: 0.2107 - accuracy: 0.9232 - val_loss: 0.3709 - val_accuracy: 0.8602
#
# Epoch 00167: saving model to Weights\Weights-167--0.86022.hdf5
# Epoch 168/1000
# 17/17 - 0s - loss: 0.2117 - accuracy: 0.9175 - val_loss: 0.3891 - val_accuracy: 0.8602
#
# Epoch 00168: saving model to Weights\Weights-168--0.86022.hdf5
# Epoch 169/1000
# 17/17 - 0s - loss: 0.2216 - accuracy: 0.9117 - val_loss: 0.3680 - val_accuracy: 0.8710
#
# Epoch 00169: saving model to Weights\Weights-169--0.87097.hdf5
# Epoch 170/1000
# 17/17 - 0s - loss: 0.2109 - accuracy: 0.9155 - val_loss: 0.3802 - val_accuracy: 0.8602
#
# Epoch 00170: saving model to Weights\Weights-170--0.86022.hdf5
# Epoch 171/1000
# 17/17 - 0s - loss: 0.2019 - accuracy: 0.9213 - val_loss: 0.3756 - val_accuracy: 0.8710
#
# Epoch 00171: saving model to Weights\Weights-171--0.87097.hdf5
# Epoch 172/1000
# 17/17 - 0s - loss: 0.2019 - accuracy: 0.9213 - val_loss: 0.3697 - val_accuracy: 0.8710
#
# Epoch 00172: saving model to Weights\Weights-172--0.87097.hdf5
# Epoch 173/1000
# 17/17 - 0s - loss: 0.2035 - accuracy: 0.9271 - val_loss: 0.3779 - val_accuracy: 0.8602
#
# Epoch 00173: saving model to Weights\Weights-173--0.86022.hdf5
# Epoch 174/1000
# 17/17 - 0s - loss: 0.2008 - accuracy: 0.9271 - val_loss: 0.3618 - val_accuracy: 0.8710
#
# Epoch 00174: saving model to Weights\Weights-174--0.87097.hdf5
# Epoch 175/1000
# 17/17 - 0s - loss: 0.1993 - accuracy: 0.9271 - val_loss: 0.3541 - val_accuracy: 0.8710
#
# Epoch 00175: saving model to Weights\Weights-175--0.87097.hdf5
# Epoch 176/1000
# 17/17 - 0s - loss: 0.1989 - accuracy: 0.9251 - val_loss: 0.3763 - val_accuracy: 0.8602
#
# Epoch 00176: saving model to Weights\Weights-176--0.86022.hdf5
# Epoch 177/1000
# 17/17 - 0s - loss: 0.2004 - accuracy: 0.9271 - val_loss: 0.3715 - val_accuracy: 0.8817
#
# Epoch 00177: saving model to Weights\Weights-177--0.88172.hdf5
# Epoch 178/1000
# 17/17 - 0s - loss: 0.2027 - accuracy: 0.9213 - val_loss: 0.3719 - val_accuracy: 0.8817
#
# Epoch 00178: saving model to Weights\Weights-178--0.88172.hdf5
# Epoch 179/1000
# 17/17 - 0s - loss: 0.2095 - accuracy: 0.9175 - val_loss: 0.4067 - val_accuracy: 0.8710
#
# Epoch 00179: saving model to Weights\Weights-179--0.87097.hdf5
# Epoch 180/1000
# 17/17 - 0s - loss: 0.2109 - accuracy: 0.9155 - val_loss: 0.3571 - val_accuracy: 0.8710
#
# Epoch 00180: saving model to Weights\Weights-180--0.87097.hdf5
# Epoch 181/1000
# 17/17 - 0s - loss: 0.2002 - accuracy: 0.9251 - val_loss: 0.3722 - val_accuracy: 0.8710
#
# Epoch 00181: saving model to Weights\Weights-181--0.87097.hdf5
# Epoch 182/1000
# 17/17 - 0s - loss: 0.2138 - accuracy: 0.9194 - val_loss: 0.3594 - val_accuracy: 0.8710
#
# Epoch 00182: saving model to Weights\Weights-182--0.87097.hdf5
# Epoch 183/1000
# 17/17 - 0s - loss: 0.2071 - accuracy: 0.9194 - val_loss: 0.3865 - val_accuracy: 0.8710
#
# Epoch 00183: saving model to Weights\Weights-183--0.87097.hdf5
# Epoch 184/1000
# 17/17 - 0s - loss: 0.2019 - accuracy: 0.9213 - val_loss: 0.3690 - val_accuracy: 0.8710
#
# Epoch 00184: saving model to Weights\Weights-184--0.87097.hdf5
# Epoch 185/1000
# 17/17 - 0s - loss: 0.1994 - accuracy: 0.9175 - val_loss: 0.3992 - val_accuracy: 0.8602
#
# Epoch 00185: saving model to Weights\Weights-185--0.86022.hdf5
# Epoch 186/1000
# 17/17 - 0s - loss: 0.2022 - accuracy: 0.9251 - val_loss: 0.3914 - val_accuracy: 0.8710
#
# Epoch 00186: saving model to Weights\Weights-186--0.87097.hdf5
# Epoch 187/1000
# 17/17 - 0s - loss: 0.2057 - accuracy: 0.9194 - val_loss: 0.3972 - val_accuracy: 0.8495
#
# Epoch 00187: saving model to Weights\Weights-187--0.84946.hdf5
# Epoch 188/1000
# 17/17 - 0s - loss: 0.2007 - accuracy: 0.9213 - val_loss: 0.3794 - val_accuracy: 0.8710
#
# Epoch 00188: saving model to Weights\Weights-188--0.87097.hdf5
# Epoch 189/1000
# 17/17 - 0s - loss: 0.1962 - accuracy: 0.9271 - val_loss: 0.3878 - val_accuracy: 0.8602
#
# Epoch 00189: saving model to Weights\Weights-189--0.86022.hdf5
# Epoch 190/1000
# 17/17 - 0s - loss: 0.1957 - accuracy: 0.9232 - val_loss: 0.3780 - val_accuracy: 0.8710
#
# Epoch 00190: saving model to Weights\Weights-190--0.87097.hdf5
# Epoch 191/1000
# 17/17 - 0s - loss: 0.1976 - accuracy: 0.9232 - val_loss: 0.3926 - val_accuracy: 0.8602
#
# Epoch 00191: saving model to Weights\Weights-191--0.86022.hdf5
# Epoch 192/1000
# 17/17 - 0s - loss: 0.1967 - accuracy: 0.9328 - val_loss: 0.3908 - val_accuracy: 0.8602
#
# Epoch 00192: saving model to Weights\Weights-192--0.86022.hdf5
# Epoch 193/1000
# 17/17 - 0s - loss: 0.1998 - accuracy: 0.9194 - val_loss: 0.3976 - val_accuracy: 0.8602
#
# Epoch 00193: saving model to Weights\Weights-193--0.86022.hdf5
# Epoch 194/1000
# 17/17 - 0s - loss: 0.2027 - accuracy: 0.9232 - val_loss: 0.3715 - val_accuracy: 0.8710
#
# Epoch 00194: saving model to Weights\Weights-194--0.87097.hdf5
# Epoch 195/1000
# 17/17 - 0s - loss: 0.1971 - accuracy: 0.9232 - val_loss: 0.3854 - val_accuracy: 0.8710
#
# Epoch 00195: saving model to Weights\Weights-195--0.87097.hdf5
# Epoch 196/1000
# 17/17 - 0s - loss: 0.1988 - accuracy: 0.9136 - val_loss: 0.4043 - val_accuracy: 0.8602
#
# Epoch 00196: saving model to Weights\Weights-196--0.86022.hdf5
# Epoch 197/1000
# 17/17 - 0s - loss: 0.1991 - accuracy: 0.9271 - val_loss: 0.3987 - val_accuracy: 0.8387
#
# Epoch 00197: saving model to Weights\Weights-197--0.83871.hdf5
# Epoch 198/1000
# 17/17 - 0s - loss: 0.1977 - accuracy: 0.9194 - val_loss: 0.3983 - val_accuracy: 0.8602
#
# Epoch 00198: saving model to Weights\Weights-198--0.86022.hdf5
# Epoch 199/1000
# 17/17 - 0s - loss: 0.1958 - accuracy: 0.9290 - val_loss: 0.3938 - val_accuracy: 0.8602
#
# Epoch 00199: saving model to Weights\Weights-199--0.86022.hdf5
# Epoch 200/1000
# 17/17 - 0s - loss: 0.2043 - accuracy: 0.9194 - val_loss: 0.4050 - val_accuracy: 0.8387
# Epoch 00200: saving model to Weights\Weights-200--0.83871.hdf5
# Epoch 201/1000
# 17/17 - 0s - loss: 0.2085 - accuracy: 0.9194 - val_loss: 0.3784 - val_accuracy: 0.8710
#
# Epoch 00201: saving model to Weights\Weights-201--0.87097.hdf5
# Epoch 202/1000
# 17/17 - 0s - loss: 0.2002 - accuracy: 0.9175 - val_loss: 0.3932 - val_accuracy: 0.8710
#
# Epoch 00202: saving model to Weights\Weights-202--0.87097.hdf5
# Epoch 203/1000
# 17/17 - 0s - loss: 0.1978 - accuracy: 0.9290 - val_loss: 0.3951 - val_accuracy: 0.8602
#
# Epoch 00203: saving model to Weights\Weights-203--0.86022.hdf5
# Epoch 204/1000
# 17/17 - 0s - loss: 0.1963 - accuracy: 0.9155 - val_loss: 0.4291 - val_accuracy: 0.8387
#
# Epoch 00204: saving model to Weights\Weights-204--0.83871.hdf5
# Epoch 205/1000
# 17/17 - 0s - loss: 0.2012 - accuracy: 0.9232 - val_loss: 0.3907 - val_accuracy: 0.8710
#
# Epoch 00205: saving model to Weights\Weights-205--0.87097.hdf5
# Epoch 206/1000
# 17/17 - 0s - loss: 0.2012 - accuracy: 0.9194 - val_loss: 0.3914 - val_accuracy: 0.8710
#
# Epoch 00206: saving model to Weights\Weights-206--0.87097.hdf5
# Epoch 207/1000
# 17/17 - 0s - loss: 0.2016 - accuracy: 0.9175 - val_loss: 0.4029 - val_accuracy: 0.8710
#
# Epoch 00207: saving model to Weights\Weights-207--0.87097.hdf5
# Epoch 208/1000
# 17/17 - 0s - loss: 0.1978 - accuracy: 0.9232 - val_loss: 0.3948 - val_accuracy: 0.8602
#
# Epoch 00208: saving model to Weights\Weights-208--0.86022.hdf5
# Epoch 209/1000
# 17/17 - 0s - loss: 0.1993 - accuracy: 0.9213 - val_loss: 0.3946 - val_accuracy: 0.8602
#
# Epoch 00209: saving model to Weights\Weights-209--0.86022.hdf5
# Epoch 210/1000
# 17/17 - 0s - loss: 0.1934 - accuracy: 0.9271 - val_loss: 0.3925 - val_accuracy: 0.8710
#
# Epoch 00210: saving model to Weights\Weights-210--0.87097.hdf5
# Epoch 211/1000
# 17/17 - 0s - loss: 0.1931 - accuracy: 0.9309 - val_loss: 0.4004 - val_accuracy: 0.8495
#
# Epoch 00211: saving model to Weights\Weights-211--0.84946.hdf5
# Epoch 212/1000
# 17/17 - 0s - loss: 0.1921 - accuracy: 0.9251 - val_loss: 0.4025 - val_accuracy: 0.8495
#
# Epoch 00212: saving model to Weights\Weights-212--0.84946.hdf5
# Epoch 213/1000
# 17/17 - 0s - loss: 0.1955 - accuracy: 0.9232 - val_loss: 0.4046 - val_accuracy: 0.8280
#
# Epoch 00213: saving model to Weights\Weights-213--0.82796.hdf5
# Epoch 214/1000
# 17/17 - 0s - loss: 0.1946 - accuracy: 0.9271 - val_loss: 0.3979 - val_accuracy: 0.8602
#
# Epoch 00214: saving model to Weights\Weights-214--0.86022.hdf5
# Epoch 215/1000
# 17/17 - 0s - loss: 0.2022 - accuracy: 0.9251 - val_loss: 0.4010 - val_accuracy: 0.8495
#
# Epoch 00215: saving model to Weights\Weights-215--0.84946.hdf5
# Epoch 216/1000
# 17/17 - 0s - loss: 0.1926 - accuracy: 0.9251 - val_loss: 0.4018 - val_accuracy: 0.8710
#
# Epoch 00216: saving model to Weights\Weights-216--0.87097.hdf5
# Epoch 217/1000
# 17/17 - 0s - loss: 0.1954 - accuracy: 0.9290 - val_loss: 0.4019 - val_accuracy: 0.8602
#
# Epoch 00217: saving model to Weights\Weights-217--0.86022.hdf5
# Epoch 218/1000
# 17/17 - 0s - loss: 0.1937 - accuracy: 0.9309 - val_loss: 0.4175 - val_accuracy: 0.8602
#
# Epoch 00218: saving model to Weights\Weights-218--0.86022.hdf5
# Epoch 219/1000
# 17/17 - 0s - loss: 0.1937 - accuracy: 0.9271 - val_loss: 0.4003 - val_accuracy: 0.8710
#
# Epoch 00219: saving model to Weights\Weights-219--0.87097.hdf5
# Epoch 220/1000
# 17/17 - 0s - loss: 0.1912 - accuracy: 0.9232 - val_loss: 0.4213 - val_accuracy: 0.8495
#
# Epoch 00220: saving model to Weights\Weights-220--0.84946.hdf5
# Epoch 221/1000
# 17/17 - 0s - loss: 0.1947 - accuracy: 0.9290 - val_loss: 0.4023 - val_accuracy: 0.8495
#
# Epoch 00221: saving model to Weights\Weights-221--0.84946.hdf5
# Epoch 222/1000
# 17/17 - 0s - loss: 0.1917 - accuracy: 0.9290 - val_loss: 0.4198 - val_accuracy: 0.8387
#
# Epoch 00222: saving model to Weights\Weights-222--0.83871.hdf5
# Epoch 223/1000
# 17/17 - 0s - loss: 0.1908 - accuracy: 0.9175 - val_loss: 0.4035 - val_accuracy: 0.8602
#
# Epoch 00223: saving model to Weights\Weights-223--0.86022.hdf5
# Epoch 224/1000
# 17/17 - 0s - loss: 0.1923 - accuracy: 0.9232 - val_loss: 0.4198 - val_accuracy: 0.8387
#
# Epoch 00224: saving model to Weights\Weights-224--0.83871.hdf5
# Epoch 225/1000
# 17/17 - 0s - loss: 0.1964 - accuracy: 0.9271 - val_loss: 0.4186 - val_accuracy: 0.8495
#
# Epoch 00225: saving model to Weights\Weights-225--0.84946.hdf5
# Epoch 226/1000
# 17/17 - 0s - loss: 0.1915 - accuracy: 0.9271 - val_loss: 0.4211 - val_accuracy: 0.8495
#
# Epoch 00226: saving model to Weights\Weights-226--0.84946.hdf5
# Epoch 227/1000
# 17/17 - 0s - loss: 0.1902 - accuracy: 0.9251 - val_loss: 0.4315 - val_accuracy: 0.8387
#
# Epoch 00227: saving model to Weights\Weights-227--0.83871.hdf5
# Epoch 228/1000
# 17/17 - 0s - loss: 0.1919 - accuracy: 0.9290 - val_loss: 0.4031 - val_accuracy: 0.8602
#
# Epoch 00228: saving model to Weights\Weights-228--0.86022.hdf5
# Epoch 229/1000
# 17/17 - 0s - loss: 0.2023 - accuracy: 0.9155 - val_loss: 0.4532 - val_accuracy: 0.8387
#
# Epoch 00229: saving model to Weights\Weights-229--0.83871.hdf5
# Epoch 230/1000
# 17/17 - 0s - loss: 0.1954 - accuracy: 0.9194 - val_loss: 0.4164 - val_accuracy: 0.8495
#
# Epoch 00230: saving model to Weights\Weights-230--0.84946.hdf5
# Epoch 231/1000
# 17/17 - 0s - loss: 0.1976 - accuracy: 0.9155 - val_loss: 0.4469 - val_accuracy: 0.8387
#
# Epoch 00231: saving model to Weights\Weights-231--0.83871.hdf5
# Epoch 232/1000
# 17/17 - 0s - loss: 0.1901 - accuracy: 0.9309 - val_loss: 0.4110 - val_accuracy: 0.8280
#
# Epoch 00232: saving model to Weights\Weights-232--0.82796.hdf5
# Epoch 233/1000
# 17/17 - 0s - loss: 0.1929 - accuracy: 0.9194 - val_loss: 0.4190 - val_accuracy: 0.8280
#
# Epoch 00233: saving model to Weights\Weights-233--0.82796.hdf5
# Epoch 234/1000
# 17/17 - 0s - loss: 0.1927 - accuracy: 0.9290 - val_loss: 0.4272 - val_accuracy: 0.8387
#
# Epoch 00234: saving model to Weights\Weights-234--0.83871.hdf5
# Epoch 235/1000
# 17/17 - 0s - loss: 0.1897 - accuracy: 0.9213 - val_loss: 0.4203 - val_accuracy: 0.8602
#
# Epoch 00235: saving model to Weights\Weights-235--0.86022.hdf5
# Epoch 236/1000
# 17/17 - 0s - loss: 0.1932 - accuracy: 0.9271 - val_loss: 0.4033 - val_accuracy: 0.8495
#
# Epoch 00236: saving model to Weights\Weights-236--0.84946.hdf5
# Epoch 237/1000
# 17/17 - 0s - loss: 0.1989 - accuracy: 0.9213 - val_loss: 0.4456 - val_accuracy: 0.8387
#
# Epoch 00237: saving model to Weights\Weights-237--0.83871.hdf5
# Epoch 238/1000
# 17/17 - 0s - loss: 0.1919 - accuracy: 0.9309 - val_loss: 0.4078 - val_accuracy: 0.8495
#
# Epoch 00238: saving model to Weights\Weights-238--0.84946.hdf5
# Epoch 239/1000
# 17/17 - 0s - loss: 0.1928 - accuracy: 0.9251 - val_loss: 0.4488 - val_accuracy: 0.8280
#
# Epoch 00239: saving model to Weights\Weights-239--0.82796.hdf5
# Epoch 240/1000
# 17/17 - 0s - loss: 0.1886 - accuracy: 0.9328 - val_loss: 0.4315 - val_accuracy: 0.8280
#
# Epoch 00240: saving model to Weights\Weights-240--0.82796.hdf5
# Epoch 241/1000
# 17/17 - 0s - loss: 0.1958 - accuracy: 0.9213 - val_loss: 0.4555 - val_accuracy: 0.8387
#
# Epoch 00241: saving model to Weights\Weights-241--0.83871.hdf5
# Epoch 242/1000
# 17/17 - 0s - loss: 0.2264 - accuracy: 0.9079 - val_loss: 0.4111 - val_accuracy: 0.8495
#
# Epoch 00242: saving model to Weights\Weights-242--0.84946.hdf5
# Epoch 243/1000
# 17/17 - 0s - loss: 0.2105 - accuracy: 0.9232 - val_loss: 0.4247 - val_accuracy: 0.8280
#
# Epoch 00243: saving model to Weights\Weights-243--0.82796.hdf5
# Epoch 244/1000
# 17/17 - 0s - loss: 0.2231 - accuracy: 0.9136 - val_loss: 0.4469 - val_accuracy: 0.8495
#
# Epoch 00244: saving model to Weights\Weights-244--0.84946.hdf5
# Epoch 245/1000
# 17/17 - 0s - loss: 0.2104 - accuracy: 0.9136 - val_loss: 0.4063 - val_accuracy: 0.8495
#
# Epoch 00245: saving model to Weights\Weights-245--0.84946.hdf5
# Epoch 246/1000
# 17/17 - 0s - loss: 0.2073 - accuracy: 0.9232 - val_loss: 0.4191 - val_accuracy: 0.8172
#
# Epoch 00246: saving model to Weights\Weights-246--0.81720.hdf5
# Epoch 247/1000
# 17/17 - 0s - loss: 0.1990 - accuracy: 0.9232 - val_loss: 0.4381 - val_accuracy: 0.8495
#
# Epoch 00247: saving model to Weights\Weights-247--0.84946.hdf5
# Epoch 248/1000
# 17/17 - 0s - loss: 0.1969 - accuracy: 0.9251 - val_loss: 0.4510 - val_accuracy: 0.8495
#
# Epoch 00248: saving model to Weights\Weights-248--0.84946.hdf5
# Epoch 249/1000
# 17/17 - 0s - loss: 0.1954 - accuracy: 0.9271 - val_loss: 0.4198 - val_accuracy: 0.8172
#
# Epoch 00249: saving model to Weights\Weights-249--0.81720.hdf5
# Epoch 250/1000
# 17/17 - 0s - loss: 0.1916 - accuracy: 0.9232 - val_loss: 0.4395 - val_accuracy: 0.8280
#
# Epoch 00250: saving model to Weights\Weights-250--0.82796.hdf5
# Epoch 251/1000
# 17/17 - 0s - loss: 0.1910 - accuracy: 0.9251 - val_loss: 0.4164 - val_accuracy: 0.8495
#
# Epoch 00251: saving model to Weights\Weights-251--0.84946.hdf5
# Epoch 252/1000
# 17/17 - 0s - loss: 0.1887 - accuracy: 0.9232 - val_loss: 0.4319 - val_accuracy: 0.8387
#
# Epoch 00252: saving model to Weights\Weights-252--0.83871.hdf5
# Epoch 253/1000
# 17/17 - 0s - loss: 0.1901 - accuracy: 0.9271 - val_loss: 0.4568 - val_accuracy: 0.8280
#
# Epoch 00253: saving model to Weights\Weights-253--0.82796.hdf5
# Epoch 254/1000
# 17/17 - 0s - loss: 0.1903 - accuracy: 0.9309 - val_loss: 0.4131 - val_accuracy: 0.8495
#
# Epoch 00254: saving model to Weights\Weights-254--0.84946.hdf5
# Epoch 255/1000
# 17/17 - 0s - loss: 0.1918 - accuracy: 0.9213 - val_loss: 0.4435 - val_accuracy: 0.8387
#
# Epoch 00255: saving model to Weights\Weights-255--0.83871.hdf5
# Epoch 256/1000
# 17/17 - 0s - loss: 0.1904 - accuracy: 0.9271 - val_loss: 0.4611 - val_accuracy: 0.8387
#
# Epoch 00256: saving model to Weights\Weights-256--0.83871.hdf5
# Epoch 257/1000
# 17/17 - 0s - loss: 0.1936 - accuracy: 0.9213 - val_loss: 0.4263 - val_accuracy: 0.8495
#
# Epoch 00257: saving model to Weights\Weights-257--0.84946.hdf5
# Epoch 258/1000
# 17/17 - 0s - loss: 0.1868 - accuracy: 0.9232 - val_loss: 0.4440 - val_accuracy: 0.8387
#
# Epoch 00258: saving model to Weights\Weights-258--0.83871.hdf5
# Epoch 259/1000
# 17/17 - 0s - loss: 0.1875 - accuracy: 0.9367 - val_loss: 0.4298 - val_accuracy: 0.8172
#
# Epoch 00259: saving model to Weights\Weights-259--0.81720.hdf5
# Epoch 260/1000
# 17/17 - 0s - loss: 0.1850 - accuracy: 0.9290 - val_loss: 0.4381 - val_accuracy: 0.8280
#
# Epoch 00260: saving model to Weights\Weights-260--0.82796.hdf5
# Epoch 261/1000
# 17/17 - 0s - loss: 0.1877 - accuracy: 0.9309 - val_loss: 0.4170 - val_accuracy: 0.8387
#
# Epoch 00261: saving model to Weights\Weights-261--0.83871.hdf5
# Epoch 262/1000
# 17/17 - 0s - loss: 0.1895 - accuracy: 0.9194 - val_loss: 0.4582 - val_accuracy: 0.8280
#
# Epoch 00262: saving model to Weights\Weights-262--0.82796.hdf5
# Epoch 263/1000
# 17/17 - 0s - loss: 0.1898 - accuracy: 0.9251 - val_loss: 0.4405 - val_accuracy: 0.8280
#
# Epoch 00263: saving model to Weights\Weights-263--0.82796.hdf5
# Epoch 264/1000
# 17/17 - 0s - loss: 0.1886 - accuracy: 0.9309 - val_loss: 0.4406 - val_accuracy: 0.8280
#
# Epoch 00264: saving model to Weights\Weights-264--0.82796.hdf5
# Epoch 265/1000
# 17/17 - 0s - loss: 0.1903 - accuracy: 0.9194 - val_loss: 0.4566 - val_accuracy: 0.8280
#
# Epoch 00265: saving model to Weights\Weights-265--0.82796.hdf5
# Epoch 266/1000
# 17/17 - 0s - loss: 0.1879 - accuracy: 0.9290 - val_loss: 0.4341 - val_accuracy: 0.8172
#
# Epoch 00266: saving model to Weights\Weights-266--0.81720.hdf5
# Epoch 267/1000
# 17/17 - 0s - loss: 0.1874 - accuracy: 0.9232 - val_loss: 0.4669 - val_accuracy: 0.8280
#
# Epoch 00267: saving model to Weights\Weights-267--0.82796.hdf5
# Epoch 268/1000
# 17/17 - 0s - loss: 0.2018 - accuracy: 0.9232 - val_loss: 0.4194 - val_accuracy: 0.8495
#
# Epoch 00268: saving model to Weights\Weights-268--0.84946.hdf5
# Epoch 269/1000
# 17/17 - 0s - loss: 0.1971 - accuracy: 0.9290 - val_loss: 0.4433 - val_accuracy: 0.8172
#
# Epoch 00269: saving model to Weights\Weights-269--0.81720.hdf5
# Epoch 270/1000
# 17/17 - 0s - loss: 0.1919 - accuracy: 0.9271 - val_loss: 0.4499 - val_accuracy: 0.8172
#
# Epoch 00270: saving model to Weights\Weights-270--0.81720.hdf5
# Epoch 271/1000
# 17/17 - 0s - loss: 0.1975 - accuracy: 0.9194 - val_loss: 0.4613 - val_accuracy: 0.8280
#
# Epoch 00271: saving model to Weights\Weights-271--0.82796.hdf5
# Epoch 272/1000
# 17/17 - 0s - loss: 0.1936 - accuracy: 0.9251 - val_loss: 0.4505 - val_accuracy: 0.8172
#
# Epoch 00272: saving model to Weights\Weights-272--0.81720.hdf5
# Epoch 273/1000
# 17/17 - 0s - loss: 0.2072 - accuracy: 0.9079 - val_loss: 0.5010 - val_accuracy: 0.8172
#
# Epoch 00273: saving model to Weights\Weights-273--0.81720.hdf5
# Epoch 274/1000
# 17/17 - 0s - loss: 0.1889 - accuracy: 0.9251 - val_loss: 0.4333 - val_accuracy: 0.8280
#
# Epoch 00274: saving model to Weights\Weights-274--0.82796.hdf5
# Epoch 275/1000
# 17/17 - 0s - loss: 0.1872 - accuracy: 0.9251 - val_loss: 0.4687 - val_accuracy: 0.8172
#
# Epoch 00275: saving model to Weights\Weights-275--0.81720.hdf5
# Epoch 276/1000
# 17/17 - 0s - loss: 0.1940 - accuracy: 0.9290 - val_loss: 0.4272 - val_accuracy: 0.8280
#
# Epoch 00276: saving model to Weights\Weights-276--0.82796.hdf5
# Epoch 277/1000
# 17/17 - 0s - loss: 0.1865 - accuracy: 0.9213 - val_loss: 0.4522 - val_accuracy: 0.8172
#
# Epoch 00277: saving model to Weights\Weights-277--0.81720.hdf5
# Epoch 278/1000
# 17/17 - 0s - loss: 0.1844 - accuracy: 0.9347 - val_loss: 0.4482 - val_accuracy: 0.8172
#
# Epoch 00278: saving model to Weights\Weights-278--0.81720.hdf5
# Epoch 279/1000
# 17/17 - 0s - loss: 0.1844 - accuracy: 0.9309 - val_loss: 0.4474 - val_accuracy: 0.8280
#
# Epoch 00279: saving model to Weights\Weights-279--0.82796.hdf5
# Epoch 280/1000
# 17/17 - 0s - loss: 0.1843 - accuracy: 0.9251 - val_loss: 0.4627 - val_accuracy: 0.8387
#
# Epoch 00280: saving model to Weights\Weights-280--0.83871.hdf5
# Epoch 281/1000
# 17/17 - 0s - loss: 0.1872 - accuracy: 0.9271 - val_loss: 0.4459 - val_accuracy: 0.8280
#
# Epoch 00281: saving model to Weights\Weights-281--0.82796.hdf5
# Epoch 282/1000
# 17/17 - 0s - loss: 0.1852 - accuracy: 0.9290 - val_loss: 0.4480 - val_accuracy: 0.8387
#
# Epoch 00282: saving model to Weights\Weights-282--0.83871.hdf5
# Epoch 283/1000
# 17/17 - 0s - loss: 0.1813 - accuracy: 0.9328 - val_loss: 0.4623 - val_accuracy: 0.8280
#
# Epoch 00283: saving model to Weights\Weights-283--0.82796.hdf5
# Epoch 284/1000
# 17/17 - 0s - loss: 0.1879 - accuracy: 0.9290 - val_loss: 0.4293 - val_accuracy: 0.8387
#
# Epoch 00284: saving model to Weights\Weights-284--0.83871.hdf5
# Epoch 285/1000
# 17/17 - 0s - loss: 0.1899 - accuracy: 0.9232 - val_loss: 0.4810 - val_accuracy: 0.8280
#
# Epoch 00285: saving model to Weights\Weights-285--0.82796.hdf5
# Epoch 286/1000
# 17/17 - 0s - loss: 0.1853 - accuracy: 0.9309 - val_loss: 0.4475 - val_accuracy: 0.8172
#
# Epoch 00286: saving model to Weights\Weights-286--0.81720.hdf5
# Epoch 287/1000
# 17/17 - 0s - loss: 0.1830 - accuracy: 0.9290 - val_loss: 0.4422 - val_accuracy: 0.8172
#
# Epoch 00287: saving model to Weights\Weights-287--0.81720.hdf5
# Epoch 288/1000
# 17/17 - 0s - loss: 0.1851 - accuracy: 0.9271 - val_loss: 0.4571 - val_accuracy: 0.8280
#
# Epoch 00288: saving model to Weights\Weights-288--0.82796.hdf5
# Epoch 289/1000
# 17/17 - 0s - loss: 0.1807 - accuracy: 0.9328 - val_loss: 0.4437 - val_accuracy: 0.8172
#
# Epoch 00289: saving model to Weights\Weights-289--0.81720.hdf5
# Epoch 290/1000
# 17/17 - 0s - loss: 0.1811 - accuracy: 0.9232 - val_loss: 0.4622 - val_accuracy: 0.8280
#
# ...
# Epoch 00904: saving model to Weights\Weights-904--0.80645.hdf5
# Epoch 905/1000
# 17/17 - 0s - loss: 0.1432 - accuracy: 0.9463 - val_loss: 0.7084 - val_accuracy: 0.8065
#
# Epoch 00905: saving model to Weights\Weights-905--0.80645.hdf5
# Epoch 906/1000
# 17/17 - 0s - loss: 0.1452 - accuracy: 0.9386 - val_loss: 0.7849 - val_accuracy: 0.7957
#
# Epoch 00906: saving model to Weights\Weights-906--0.79570.hdf5
# Epoch 907/1000
# 17/17 - 0s - loss: 0.1442 - accuracy: 0.9443 - val_loss: 0.8080 - val_accuracy: 0.7957
#
# Epoch 00907: saving model to Weights\Weights-907--0.79570.hdf5
# Epoch 908/1000
# 17/17 - 0s - loss: 0.1432 - accuracy: 0.9443 - val_loss: 0.7559 - val_accuracy: 0.7849
#
# Epoch 00908: saving model to Weights\Weights-908--0.78495.hdf5
# Epoch 909/1000
# 17/17 - 0s - loss: 0.1431 - accuracy: 0.9443 - val_loss: 0.8042 - val_accuracy: 0.7957
#
# Epoch 00909: saving model to Weights\Weights-909--0.79570.hdf5
# Epoch 910/1000
# 17/17 - 0s - loss: 0.1432 - accuracy: 0.9443 - val_loss: 0.7939 - val_accuracy: 0.7849
#
# Epoch 00910: saving model to Weights\Weights-910--0.78495.hdf5
# Epoch 911/1000
# 17/17 - 0s - loss: 0.1451 - accuracy: 0.9405 - val_loss: 0.8413 - val_accuracy: 0.7849
#
# Epoch 00911: saving model to Weights\Weights-911--0.78495.hdf5
# Epoch 912/1000
# 17/17 - 0s - loss: 0.1454 - accuracy: 0.9443 - val_loss: 0.7950 - val_accuracy: 0.7957
#
# Epoch 00912: saving model to Weights\Weights-912--0.79570.hdf5
# Epoch 913/1000
# 17/17 - 0s - loss: 0.1518 - accuracy: 0.9386 - val_loss: 0.8755 - val_accuracy: 0.7957
#
# Epoch 00913: saving model to Weights\Weights-913--0.79570.hdf5
# Epoch 914/1000
# 17/17 - 0s - loss: 0.1496 - accuracy: 0.9424 - val_loss: 0.7393 - val_accuracy: 0.8065
#
# Epoch 00914: saving model to Weights\Weights-914--0.80645.hdf5
# Epoch 915/1000
# 17/17 - 0s - loss: 0.1498 - accuracy: 0.9405 - val_loss: 0.7751 - val_accuracy: 0.8065
#
# Epoch 00915: saving model to Weights\Weights-915--0.80645.hdf5
# Epoch 916/1000
# 17/17 - 0s - loss: 0.1579 - accuracy: 0.9328 - val_loss: 0.8198 - val_accuracy: 0.7957
#
# Epoch 00916: saving model to Weights\Weights-916--0.79570.hdf5
# Epoch 917/1000
# 17/17 - 0s - loss: 0.1921 - accuracy: 0.9175 - val_loss: 0.8540 - val_accuracy: 0.8387
#
# Epoch 00917: saving model to Weights\Weights-917--0.83871.hdf5
# Epoch 918/1000
# 17/17 - 0s - loss: 0.1711 - accuracy: 0.9328 - val_loss: 0.7930 - val_accuracy: 0.7957
#
# Epoch 00918: saving model to Weights\Weights-918--0.79570.hdf5
# Epoch 919/1000
# 17/17 - 0s - loss: 0.1474 - accuracy: 0.9424 - val_loss: 0.6643 - val_accuracy: 0.7957
#
# Epoch 00919: saving model to Weights\Weights-919--0.79570.hdf5
# Epoch 920/1000
# 17/17 - 0s - loss: 0.1455 - accuracy: 0.9443 - val_loss: 0.6853 - val_accuracy: 0.8065
#
# Epoch 00920: saving model to Weights\Weights-920--0.80645.hdf5
# Epoch 921/1000
# 17/17 - 0s - loss: 0.1453 - accuracy: 0.9424 - val_loss: 0.6919 - val_accuracy: 0.8065
#
# Epoch 00921: saving model to Weights\Weights-921--0.80645.hdf5
# Epoch 922/1000
# 17/17 - 0s - loss: 0.1445 - accuracy: 0.9463 - val_loss: 0.7048 - val_accuracy: 0.7957
#
# Epoch 00922: saving model to Weights\Weights-922--0.79570.hdf5
# Epoch 923/1000
# 17/17 - 0s - loss: 0.1574 - accuracy: 0.9367 - val_loss: 0.7768 - val_accuracy: 0.8172
#
# Epoch 00923: saving model to Weights\Weights-923--0.81720.hdf5
# Epoch 924/1000
# 17/17 - 0s - loss: 0.1490 - accuracy: 0.9386 - val_loss: 0.6912 - val_accuracy: 0.8280
#
# Epoch 00924: saving model to Weights\Weights-924--0.82796.hdf5
# Epoch 925/1000
# 17/17 - 0s - loss: 0.1645 - accuracy: 0.9424 - val_loss: 0.8698 - val_accuracy: 0.8280
#
# Epoch 00925: saving model to Weights\Weights-925--0.82796.hdf5
# Epoch 926/1000
# 17/17 - 0s - loss: 0.1485 - accuracy: 0.9386 - val_loss: 0.7622 - val_accuracy: 0.7849
#
# Epoch 00926: saving model to Weights\Weights-926--0.78495.hdf5
# Epoch 927/1000
# 17/17 - 0s - loss: 0.1497 - accuracy: 0.9443 - val_loss: 0.7454 - val_accuracy: 0.8065
#
# Epoch 00927: saving model to Weights\Weights-927--0.80645.hdf5
# Epoch 928/1000
# 17/17 - 0s - loss: 0.1499 - accuracy: 0.9367 - val_loss: 0.8452 - val_accuracy: 0.7957
#
# Epoch 00928: saving model to Weights\Weights-928--0.79570.hdf5
# Epoch 929/1000
# 17/17 - 0s - loss: 0.1458 - accuracy: 0.9482 - val_loss: 0.6906 - val_accuracy: 0.8065
#
# Epoch 00929: saving model to Weights\Weights-929--0.80645.hdf5
# Epoch 930/1000
# 17/17 - 0s - loss: 0.1437 - accuracy: 0.9386 - val_loss: 0.7590 - val_accuracy: 0.8065
#
# Epoch 00930: saving model to Weights\Weights-930--0.80645.hdf5
# Epoch 931/1000
# 17/17 - 0s - loss: 0.1430 - accuracy: 0.9463 - val_loss: 0.7395 - val_accuracy: 0.8065
#
# Epoch 00931: saving model to Weights\Weights-931--0.80645.hdf5
# Epoch 932/1000
# 17/17 - 0s - loss: 0.1394 - accuracy: 0.9501 - val_loss: 0.7244 - val_accuracy: 0.8172
#
# Epoch 00932: saving model to Weights\Weights-932--0.81720.hdf5
# Epoch 933/1000
# 17/17 - 0s - loss: 0.1422 - accuracy: 0.9424 - val_loss: 0.7139 - val_accuracy: 0.8065
#
# Epoch 00933: saving model to Weights\Weights-933--0.80645.hdf5
# Epoch 934/1000
# 17/17 - 0s - loss: 0.1416 - accuracy: 0.9443 - val_loss: 0.7212 - val_accuracy: 0.8065
#
# Epoch 00934: saving model to Weights\Weights-934--0.80645.hdf5
# Epoch 935/1000
# 17/17 - 0s - loss: 0.1427 - accuracy: 0.9405 - val_loss: 0.7403 - val_accuracy: 0.7957
#
# Epoch 00935: saving model to Weights\Weights-935--0.79570.hdf5
# Epoch 936/1000
# 17/17 - 0s - loss: 0.1421 - accuracy: 0.9443 - val_loss: 0.7497 - val_accuracy: 0.7957
#
# Epoch 00936: saving model to Weights\Weights-936--0.79570.hdf5
# Epoch 937/1000
# 17/17 - 0s - loss: 0.1398 - accuracy: 0.9463 - val_loss: 0.7863 - val_accuracy: 0.7957
#
# Epoch 00937: saving model to Weights\Weights-937--0.79570.hdf5
# Epoch 938/1000
# 17/17 - 0s - loss: 0.1419 - accuracy: 0.9405 - val_loss: 0.7468 - val_accuracy: 0.7957
#
# Epoch 00938: saving model to Weights\Weights-938--0.79570.hdf5
# Epoch 939/1000
# 17/17 - 0s - loss: 0.1399 - accuracy: 0.9443 - val_loss: 0.7655 - val_accuracy: 0.7957
#
# Epoch 00939: saving model to Weights\Weights-939--0.79570.hdf5
# Epoch 940/1000
# 17/17 - 0s - loss: 0.1390 - accuracy: 0.9443 - val_loss: 0.7576 - val_accuracy: 0.7957
#
# Epoch 00940: saving model to Weights\Weights-940--0.79570.hdf5
# Epoch 941/1000
# 17/17 - 0s - loss: 0.1454 - accuracy: 0.9443 - val_loss: 0.8134 - val_accuracy: 0.7957
#
# Epoch 00941: saving model to Weights\Weights-941--0.79570.hdf5
# Epoch 942/1000
# 17/17 - 0s - loss: 0.1432 - accuracy: 0.9405 - val_loss: 0.8254 - val_accuracy: 0.7957
#
# Epoch 00942: saving model to Weights\Weights-942--0.79570.hdf5
# Epoch 943/1000
# 17/17 - 0s - loss: 0.1402 - accuracy: 0.9424 - val_loss: 0.8007 - val_accuracy: 0.7957
#
# Epoch 00943: saving model to Weights\Weights-943--0.79570.hdf5
# Epoch 944/1000
# 17/17 - 0s - loss: 0.1379 - accuracy: 0.9482 - val_loss: 0.7969 - val_accuracy: 0.7957
# Epoch 00944: saving model to Weights\Weights-944--0.79570.hdf5
# Epoch 945/1000
# 17/17 - 0s - loss: 0.1384 - accuracy: 0.9443 - val_loss: 0.8186 - val_accuracy: 0.7849
#
# Epoch 00945: saving model to Weights\Weights-945--0.78495.hdf5
# Epoch 946/1000
# 17/17 - 0s - loss: 0.1417 - accuracy: 0.9424 - val_loss: 0.8885 - val_accuracy: 0.7957
#
# Epoch 00946: saving model to Weights\Weights-946--0.79570.hdf5
# Epoch 947/1000
# 17/17 - 0s - loss: 0.1414 - accuracy: 0.9386 - val_loss: 0.8000 - val_accuracy: 0.7849
#
# Epoch 00947: saving model to Weights\Weights-947--0.78495.hdf5
# Epoch 948/1000
# 17/17 - 0s - loss: 0.1455 - accuracy: 0.9386 - val_loss: 0.8242 - val_accuracy: 0.7957
#
# Epoch 00948: saving model to Weights\Weights-948--0.79570.hdf5
# Epoch 949/1000
# 17/17 - 0s - loss: 0.1416 - accuracy: 0.9424 - val_loss: 0.8427 - val_accuracy: 0.7957
#
# Epoch 00949: saving model to Weights\Weights-949--0.79570.hdf5
# Epoch 950/1000
# 17/17 - 0s - loss: 0.1415 - accuracy: 0.9463 - val_loss: 0.8156 - val_accuracy: 0.7849
#
# Epoch 00950: saving model to Weights\Weights-950--0.78495.hdf5
# Epoch 951/1000
# 17/17 - 0s - loss: 0.1430 - accuracy: 0.9405 - val_loss: 0.8763 - val_accuracy: 0.7957
#
# Epoch 00951: saving model to Weights\Weights-951--0.79570.hdf5
# Epoch 952/1000
# 17/17 - 0s - loss: 0.1402 - accuracy: 0.9443 - val_loss: 0.8591 - val_accuracy: 0.7849
#
# Epoch 00952: saving model to Weights\Weights-952--0.78495.hdf5
# Epoch 953/1000
# 17/17 - 0s - loss: 0.1385 - accuracy: 0.9463 - val_loss: 0.8505 - val_accuracy: 0.7957
#
# Epoch 00953: saving model to Weights\Weights-953--0.79570.hdf5
# Epoch 954/1000
# 17/17 - 0s - loss: 0.1404 - accuracy: 0.9405 - val_loss: 0.8604 - val_accuracy: 0.7849
#
# Epoch 00954: saving model to Weights\Weights-954--0.78495.hdf5
# Epoch 955/1000
# 17/17 - 0s - loss: 0.1398 - accuracy: 0.9482 - val_loss: 0.8803 - val_accuracy: 0.7957
#
# Epoch 00955: saving model to Weights\Weights-955--0.79570.hdf5
# Epoch 956/1000
# 17/17 - 0s - loss: 0.1400 - accuracy: 0.9405 - val_loss: 0.8422 - val_accuracy: 0.7957
#
# Epoch 00956: saving model to Weights\Weights-956--0.79570.hdf5
# Epoch 957/1000
# 17/17 - 0s - loss: 0.1417 - accuracy: 0.9424 - val_loss: 0.8772 - val_accuracy: 0.7849
#
# Epoch 00957: saving model to Weights\Weights-957--0.78495.hdf5
# Epoch 958/1000
# 17/17 - 0s - loss: 0.1396 - accuracy: 0.9443 - val_loss: 0.8867 - val_accuracy: 0.7957
#
# Epoch 00958: saving model to Weights\Weights-958--0.79570.hdf5
# Epoch 959/1000
# 17/17 - 0s - loss: 0.1388 - accuracy: 0.9424 - val_loss: 0.8341 - val_accuracy: 0.7957
#
# Epoch 00959: saving model to Weights\Weights-959--0.79570.hdf5
# Epoch 960/1000
# 17/17 - 0s - loss: 0.1401 - accuracy: 0.9424 - val_loss: 0.8547 - val_accuracy: 0.7849
#
# Epoch 00960: saving model to Weights\Weights-960--0.78495.hdf5
# Epoch 961/1000
# 17/17 - 0s - loss: 0.1437 - accuracy: 0.9367 - val_loss: 0.8184 - val_accuracy: 0.7957
#
# Epoch 00961: saving model to Weights\Weights-961--0.79570.hdf5
# Epoch 962/1000
# 17/17 - 0s - loss: 0.1443 - accuracy: 0.9405 - val_loss: 0.7477 - val_accuracy: 0.7957
#
# Epoch 00962: saving model to Weights\Weights-962--0.79570.hdf5
# Epoch 963/1000
# 17/17 - 0s - loss: 0.1451 - accuracy: 0.9367 - val_loss: 0.8186 - val_accuracy: 0.7957
#
# Epoch 00963: saving model to Weights\Weights-963--0.79570.hdf5
# Epoch 964/1000
# 17/17 - 0s - loss: 0.1534 - accuracy: 0.9328 - val_loss: 0.8646 - val_accuracy: 0.8280
#
# Epoch 00964: saving model to Weights\Weights-964--0.82796.hdf5
# Epoch 965/1000
# 17/17 - 0s - loss: 0.1562 - accuracy: 0.9328 - val_loss: 0.8226 - val_accuracy: 0.7957
#
# Epoch 00965: saving model to Weights\Weights-965--0.79570.hdf5
# Epoch 966/1000
# 17/17 - 0s - loss: 0.1424 - accuracy: 0.9424 - val_loss: 0.9480 - val_accuracy: 0.7957
#
# Epoch 00966: saving model to Weights\Weights-966--0.79570.hdf5
# Epoch 967/1000
# 17/17 - 0s - loss: 0.1585 - accuracy: 0.9328 - val_loss: 0.7302 - val_accuracy: 0.8065
#
# Epoch 00967: saving model to Weights\Weights-967--0.80645.hdf5
# Epoch 968/1000
# 17/17 - 0s - loss: 0.1537 - accuracy: 0.9328 - val_loss: 0.8081 - val_accuracy: 0.7957
#
# Epoch 00968: saving model to Weights\Weights-968--0.79570.hdf5
# Epoch 969/1000
# 17/17 - 0s - loss: 0.1512 - accuracy: 0.9347 - val_loss: 0.7926 - val_accuracy: 0.8065
#
# Epoch 00969: saving model to Weights\Weights-969--0.80645.hdf5
# Epoch 970/1000
# 17/17 - 0s - loss: 0.1491 - accuracy: 0.9367 - val_loss: 0.8000 - val_accuracy: 0.7957
#
# Epoch 00970: saving model to Weights\Weights-970--0.79570.hdf5
# Epoch 971/1000
# 17/17 - 0s - loss: 0.1437 - accuracy: 0.9386 - val_loss: 0.8810 - val_accuracy: 0.7957
#
# Epoch 00971: saving model to Weights\Weights-971--0.79570.hdf5
# Epoch 972/1000
# 17/17 - 0s - loss: 0.1417 - accuracy: 0.9424 - val_loss: 0.8424 - val_accuracy: 0.7849
#
# Epoch 00972: saving model to Weights\Weights-972--0.78495.hdf5
# Epoch 973/1000
# 17/17 - 0s - loss: 0.1455 - accuracy: 0.9328 - val_loss: 0.8487 - val_accuracy: 0.7849
#
# Epoch 00973: saving model to Weights\Weights-973--0.78495.hdf5
# Epoch 974/1000
# 17/17 - 0s - loss: 0.1535 - accuracy: 0.9328 - val_loss: 0.9240 - val_accuracy: 0.7742
#
# Epoch 00974: saving model to Weights\Weights-974--0.77419.hdf5
# Epoch 975/1000
# 17/17 - 0s - loss: 0.1428 - accuracy: 0.9405 - val_loss: 0.8857 - val_accuracy: 0.8065
#
# Epoch 00975: saving model to Weights\Weights-975--0.80645.hdf5
# Epoch 976/1000
# 17/17 - 0s - loss: 0.1522 - accuracy: 0.9367 - val_loss: 0.7928 - val_accuracy: 0.7957
#
# Epoch 00976: saving model to Weights\Weights-976--0.79570.hdf5
# Epoch 977/1000
# 17/17 - 0s - loss: 0.1393 - accuracy: 0.9405 - val_loss: 0.8239 - val_accuracy: 0.7849
#
# Epoch 00977: saving model to Weights\Weights-977--0.78495.hdf5
# Epoch 978/1000
# 17/17 - 0s - loss: 0.1378 - accuracy: 0.9405 - val_loss: 0.8225 - val_accuracy: 0.7849
#
# Epoch 00978: saving model to Weights\Weights-978--0.78495.hdf5
# Epoch 979/1000
# 17/17 - 0s - loss: 0.1433 - accuracy: 0.9405 - val_loss: 0.8457 - val_accuracy: 0.7849
#
# Epoch 00979: saving model to Weights\Weights-979--0.78495.hdf5
# Epoch 980/1000
# 17/17 - 0s - loss: 0.1465 - accuracy: 0.9424 - val_loss: 0.8977 - val_accuracy: 0.7957
#
# Epoch 00980: saving model to Weights\Weights-980--0.79570.hdf5
# Epoch 981/1000
# 17/17 - 0s - loss: 0.1405 - accuracy: 0.9405 - val_loss: 0.8298 - val_accuracy: 0.7849
#
# Epoch 00981: saving model to Weights\Weights-981--0.78495.hdf5
# Epoch 982/1000
# 17/17 - 0s - loss: 0.1386 - accuracy: 0.9424 - val_loss: 0.8579 - val_accuracy: 0.7957
#
# Epoch 00982: saving model to Weights\Weights-982--0.79570.hdf5
# Epoch 983/1000
# 17/17 - 0s - loss: 0.1429 - accuracy: 0.9405 - val_loss: 0.8711 - val_accuracy: 0.7742
#
# Epoch 00983: saving model to Weights\Weights-983--0.77419.hdf5
# Epoch 984/1000
# 17/17 - 0s - loss: 0.1480 - accuracy: 0.9367 - val_loss: 0.8251 - val_accuracy: 0.7849
#
# Epoch 00984: saving model to Weights\Weights-984--0.78495.hdf5
# Epoch 985/1000
# 17/17 - 0s - loss: 0.1383 - accuracy: 0.9405 - val_loss: 0.8961 - val_accuracy: 0.7957
#
# Epoch 00985: saving model to Weights\Weights-985--0.79570.hdf5
# Epoch 986/1000
# 17/17 - 0s - loss: 0.1389 - accuracy: 0.9443 - val_loss: 0.9006 - val_accuracy: 0.7957
#
# Epoch 00986: saving model to Weights\Weights-986--0.79570.hdf5
# Epoch 987/1000
# 17/17 - 0s - loss: 0.1414 - accuracy: 0.9347 - val_loss: 0.9103 - val_accuracy: 0.7849
#
# Epoch 00987: saving model to Weights\Weights-987--0.78495.hdf5
# Epoch 988/1000
# 17/17 - 0s - loss: 0.1366 - accuracy: 0.9405 - val_loss: 0.9542 - val_accuracy: 0.7957
#
# Epoch 00988: saving model to Weights\Weights-988--0.79570.hdf5
# Epoch 989/1000
# 17/17 - 0s - loss: 0.1377 - accuracy: 0.9405 - val_loss: 0.9312 - val_accuracy: 0.7957
#
# Epoch 00989: saving model to Weights\Weights-989--0.79570.hdf5
# Epoch 990/1000
# 17/17 - 0s - loss: 0.1348 - accuracy: 0.9443 - val_loss: 0.9091 - val_accuracy: 0.7849
#
# Epoch 00990: saving model to Weights\Weights-990--0.78495.hdf5
# Epoch 991/1000
# 17/17 - 0s - loss: 0.1386 - accuracy: 0.9386 - val_loss: 0.9821 - val_accuracy: 0.7957
#
# Epoch 00991: saving model to Weights\Weights-991--0.79570.hdf5
# Epoch 992/1000
# 17/17 - 0s - loss: 0.1411 - accuracy: 0.9386 - val_loss: 0.9243 - val_accuracy: 0.7849
#
# Epoch 00992: saving model to Weights\Weights-992--0.78495.hdf5
# Epoch 993/1000
# 17/17 - 0s - loss: 0.1361 - accuracy: 0.9424 - val_loss: 0.9531 - val_accuracy: 0.7957
#
# Epoch 00993: saving model to Weights\Weights-993--0.79570.hdf5
# Epoch 994/1000
# 17/17 - 0s - loss: 0.1349 - accuracy: 0.9386 - val_loss: 0.9098 - val_accuracy: 0.7849
#
# Epoch 00994: saving model to Weights\Weights-994--0.78495.hdf5
# Epoch 995/1000
# 17/17 - 0s - loss: 0.1359 - accuracy: 0.9386 - val_loss: 0.9913 - val_accuracy: 0.7957
#
# Epoch 00995: saving model to Weights\Weights-995--0.79570.hdf5
# Epoch 996/1000
# 17/17 - 0s - loss: 0.1360 - accuracy: 0.9443 - val_loss: 0.9424 - val_accuracy: 0.7849
#
# Epoch 00996: saving model to Weights\Weights-996--0.78495.hdf5
# Epoch 997/1000
# 17/17 - 0s - loss: 0.1457 - accuracy: 0.9386 - val_loss: 0.8309 - val_accuracy: 0.7957
#
# Epoch 00997: saving model to Weights\Weights-997--0.79570.hdf5
# Epoch 998/1000
# 17/17 - 0s - loss: 0.1502 - accuracy: 0.9328 - val_loss: 0.8474 - val_accuracy: 0.7957
#
# Epoch 00998: saving model to Weights\Weights-998--0.79570.hdf5
# Epoch 999/1000
# 17/17 - 0s - loss: 0.1467 - accuracy: 0.9347 - val_loss: 0.8945 - val_accuracy: 0.7957
#
# Epoch 00999: saving model to Weights\Weights-999--0.79570.hdf5
# Epoch 1000/1000
# 17/17 - 0s - loss: 0.1527 - accuracy: 0.9347 - val_loss: 0.7372 - val_accuracy: 0.7957
#
# Epoch 01000: saving model to Weights\Weights-1000--0.79570.hdf5

# %%
callbacks_list

# %%
# Let's measure final performance
hist = pd.DataFrame(neural_pred.history)
hist['epoch'] = neural_pred.epoch
hist.tail()
# Out:
#          loss  accuracy  val_loss  val_accuracy  epoch
# 995  0.136027  0.944338  0.942396      0.784946    995
# 996  0.145679  0.938580  0.830887      0.795699    996
# 997  0.150234  0.932822  0.847449      0.795699    997
# 998  0.146667  0.934741  0.894451      0.795699    998
# 999  0.152684  0.934741  0.737208      0.795699    999

# %%
hist
# Out:
#          loss  accuracy  val_loss  val_accuracy  epoch
# 0    0.995008  0.366603  0.797868      0.376344      0
# 1    0.696797  0.589251  0.653901      0.709677      1
# 2    0.647275  0.715931  0.615618      0.784946      2
# 3    0.621690  0.733205  0.573780      0.817204      3
# 4    0.582546  0.737044  0.514401      0.827957      4
# ..        ...       ...       ...           ...    ...
# 995  0.136027  0.944338  0.942396      0.784946    995
# 996  0.145679  0.938580  0.830887      0.795699    996
# 997  0.150234  0.932822  0.847449      0.795699    997
# 998  0.146667  0.934741  0.894451      0.795699    998
# 999  0.152684  0.934741  0.737208      0.795699    999
#
# [1000 rows x 5 columns]

# %%
hist['val_accuracy']
# Out:
# 0      0.376344
# 1      0.709677
# 2      0.784946
# 3      0.817204
# 4      0.827957
#          ...
# 995    0.784946
# 996    0.795699
# 997    0.795699
# 998    0.795699
# 999    0.795699
# Name: val_accuracy, Length: 1000, dtype: float64

# %%
hist['val_accuracy'].max()
# Out:
# 0.9032257795333862

# %%
hist[hist['val_accuracy']>0.91]
# Out:
# Empty DataFrame
# Columns: [loss, accuracy, val_loss, val_accuracy, epoch]
# Index: []

# %%
# multiple line plots
plt.figure(figsize= (15,12))

#plt.plot( 'epoch', 'loss', data=hist, marker='o', markerfacecolor='blue', markersize=12, color='skyblue', linewidth=4)
plt.plot( 'epoch', 'accuracy', data=hist, marker='', color='olive', linewidth=2)
plt.plot( 'epoch', 'val_accuracy', data=hist, marker='', color='olive', linewidth=2, linestyle='dashed', label="val_accuracy")
# show legend
plt.legend()

# show graph
plt.show()

# %%
neural_model

# %%
neural_test=neural_model.predict(X_test)

# %%
neural_test_converted=[]
for i in neural_test:
    if i>0.5:
        neural_test_converted.append(1)
    else:
        neural_test_converted.append(0)

# %%
cmp_list=accuracy_score(neural_test_converted,y_test)

# %%
cmp_list
# Out:
# 0.8506493506493507

# %%
neural_model.load_weights("Weights/Weights-137--0.88172.hdf5")

# %%
neural_test=neural_model.predict(X_test)

# %%
neural_test_converted=[]
for i in neural_test:
    if i>0.5:
        neural_test_converted.append(1)
    else:
        neural_test_converted.append(0)

# %%
cmp_list=accuracy_score(neural_test_converted,y_test)

# %%
cmp_list
# Out:
# 0.8181818181818182

# %%
import pickle
# Lets dump our SVM model
pickle.dump(svm_model, open('svm_model.pkl','wb'))
